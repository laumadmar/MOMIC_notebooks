# %% [markdown]
# # Task 6 Gene-wise statistics (MAGMA)
#
# In gene analysis, genetic marker data is aggregated to the level of whole genes, testing the joint association of all markers in the gene with the phenotype. Similarly, in gene-set analysis individual genes are aggregated to groups of genes sharing certain biological, functional or other characteristics.
#
# This is done using MAGMA[1]. The gene-set analysis is divided into two distinct and largely independent parts. In the first part a gene analysis is performed to quantify the degree of association each gene has with the phenotype. In addition the correlations between genes are estimated. These correlations reflect the LD between genes, and are needed in order to compensate for the dependencies between genes during the gene-set analysis. The gene p-values and gene correlation matrix are then used in the second part to perform the actual gene-set analysis.
#
#
# [1] de Leeuw CA, Mooij JM, Heskes T, Posthuma D. MAGMA: generalized gene-set analysis of GWAS data. PLoS computational biology. https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4401657/. Published April 17, 2015. Accessed August 18, 2020.

# %%
# %load_ext rpy2.ipython

# %%
import os

# Create directories for the output files
path="/mnt/data/GWAS/output/build37/task6_genewise"
if not os.path.exists(path):
    os.makedirs(path)

# %%
# %env path=/mnt/data/GWAS/output/build37/task6_genewise
# %env task3path= /mnt/data/GWAS/output/build37/task3_imputation/imputed_files
# %env task4path= /mnt/data/GWAS/output/build37/task4_assoc
# Out:
# env: path=/mnt/data/GWAS/output/build37/task6_genewise
# env: task3path=/mnt/data/GWAS/output/build37/task3_imputation/imputed_files
# env: task4path=/mnt/data/GWAS/output/build37/task4_assoc

# %% [markdown]
# **Filter out low frequency SNPs (MAF<0.01) for MAGMA**

# %%
# %%bash
# awk '{OFS="\t"; if($6>0.01 && $6<0.99) print $0}' | sed 's/ /\t/g' $task4path/dataset.b37.imputed.assoc.dosage.clean.rs.200kb.annot > $path/dataset.b37.imputed.assoc.dosage.clean.rs.200kb.annot.maf.0.01
# wc $path/dataset.b37.imputed.assoc.dosage.clean.rs.200kb.annot.maf.0.01

# %%
# %%bash
# head $path/dataset.b37.imputed.assoc.dosage.clean.rs.200kb.annot.maf.0.01
# Out:
# CHR	BP	SNP	A1	A2	FRQ	INFO	OR	SE	P	RS	ANNOT
# 10	100000625	10:100000625:A:G	A	G	0.4496	0.9979	1.2232	0.2799	0.4717	rs7899632	HPS1(-175.3kb)|LOXL4(-6.817kb)|MIR1287(-154.3kb)|MIR4685(-190.4kb)|PYROXD2(-142.7kb)|R3HCC1L(0)
# 10	100000645	10:100000645:A:C	A	C	0.2238	0.9554	0.6617	0.3298	0.2105	rs61875309	HPS1(-175.3kb)|LOXL4(-6.797kb)|MIR1287(-154.3kb)|MIR4685(-190.4kb)|PYROXD2(-142.7kb)|R3HCC1L(0)
# 10	100001867	10:100001867:C:T	C	T	0.0105	0.9292	1.2906	1.0324	0.8048	rs150203744	HPS1(-174.1kb)|LOXL4(-5.575kb)|MIR1287(-153.1kb)|MIR4685(-189.2kb)|PYROXD2(-141.5kb)|R3HCC1L(0)
# 10	100002464	10:100002464:T:C	T	C	0.0112	0.9812	0.7513	1.0186	0.7789	rs111551711	HPS1(-173.5kb)|LOXL4(-4.978kb)|MIR1287(-152.5kb)|MIR4685(-188.6kb)|PYROXD2(-140.9kb)|R3HCC1L(0)
# 10	100003242	10:100003242:T:G	T	G	0.1401	1.0713	1.9542	0.3874	0.08371	rs12258651	HPS1(-172.7kb)|LOXL4(-4.2kb)|MIR1287(-151.7kb)|MIR4685(-187.8kb)|PYROXD2(-140.1kb)|R3HCC1L(0)
# 10	100003304	10:100003304:A:G	A	G	0.0362	0.9602	2.6659	0.7874	0.213	rs72828461	HPS1(-172.6kb)|LOXL4(-4.138kb)|MIR1287(-151.7kb)|MIR4685(-187.7kb)|PYROXD2(-140kb)|R3HCC1L(0)
# 10	100003785	10:100003785:T:C	T	C	0.3236	0.9361	1.1277	0.2847	0.6729	rs1359508	HPS1(-172.2kb)|LOXL4(-3.657kb)|MIR1287(-151.2kb)|MIR4685(-187.3kb)|PYROXD2(-139.5kb)|R3HCC1L(0)
# 10	100004360	10:100004360:G:A	G	A	0.2238	0.9554	0.6617	0.3298	0.2105	rs1048754	HPS1(-171.6kb)|LOXL4(-3.082kb)|MIR1287(-150.6kb)|MIR4685(-186.7kb)|PYROXD2(-139kb)|R3HCC1L(0)
# 10	100004441	10:100004441:G:C	G	C	0.6734	0.9275	0.906	0.2859	0.7298	rs1048757	HPS1(-171.5kb)|LOXL4(-3.001kb)|MIR1287(-150.5kb)|MIR4685(-186.6kb)|PYROXD2(-138.9kb)|R3HCC1L(0)

# %%
# %%bash
# # Generate  *.SNP.LOC (SNP, CHR,BP) and *.SNP.VAL files
#
# awk 'BEGIN{OFS="\t";print "SNP","CHR","BP"};{OFS="\t"; if(NR>1)  print $11,$1,$2}' $path/dataset.b37.imputed.assoc.dosage.clean.rs.200kb.annot.maf.0.01 > $path/dataset.b37.imputed.dosage.maf.0.01.SNP.LOC
# awk 'BEGIN{OFS="\t";print "SNP","P"};{OFS="\t"; if(NR>1) print $11,$10}' $path/dataset.b37.imputed.assoc.dosage.clean.rs.200kb.annot.maf.0.01 | sed 's/e/E/g' > $path/dataset.b37.imputed.dosage.maf.0.01.SNP.PVAL
#
# head -3 $path/dataset.b37.imputed.dosage.maf.0.01.SNP.LOC
# head -3  $path/dataset.b37.imputed.dosage.maf.0.01.SNP.PVAL
# Out:
# SNP	CHR	BP
# rs7899632	10	100000625
# rs61875309	10	100000645
# SNP	P
# rs7899632	0.4717
# rs61875309	0.2105

# %% [markdown]
# **de 200 kb pasa a 50kb - esta bien?**

# %%
# %%bash
# # Annotate
# /usr/lib/magma/magma --annotate window=50,50 --snp-loc $path/dataset.b37.imputed.dosage.maf.0.01.SNP.LOC --gene-loc /mnt/data/GWAS/ref_files/NCBI37.3.gene.loc --out $path/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb
# head -3 $path/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot
# Out:
# Welcome to MAGMA v1.06 (linux)
# Using flags:
# 	--annotate window=50,50
# 	--snp-loc /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.SNP.LOC
# 	--gene-loc /mnt/data/GWAS/ref_files/NCBI37.3.gene.loc
# 	--out /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb
#
# Start time is 11:49:16, Sunday 14 Mar 2021
#
# Starting annotation...
# Reading gene locations from file /mnt/data/GWAS/ref_files/NCBI37.3.gene.loc...
# 	adding window: 50000bp
# 	19427 gene locations read from file
# 	chromosome  1: 2016 genes
# 	chromosome  2: 1226 genes
# 	chromosome  3: 1050 genes
# 	chromosome  4: 745 genes
# 	chromosome  5: 856 genes
# 	chromosome  6: 1016 genes
# 	chromosome  7: 906 genes
# 	chromosome  8: 669 genes
# 	chromosome  9: 775 genes
# 	chromosome 10: 723 genes
# 	chromosome 11: 1275 genes
# 	chromosome 12: 1009 genes
# 	chromosome 13: 320 genes
# 	chromosome 14: 595 genes
# 	chromosome 15: 586 genes
# 	chromosome 16: 817 genes
# 	chromosome 17: 1147 genes
# 	chromosome 18: 271 genes
# 	chromosome 19: 1389 genes
# 	chromosome 20: 527 genes
# 	chromosome 21: 215 genes
# 	chromosome 22: 442 genes
# 	chromosome  X: 805 genes
# 	chromosome  Y: 47 genes
# Reading SNP locations from file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.SNP.LOC...
# 	WARNING: on line 1, chromosome code 'CHR' not recognised; skipping SNP (ID = SNP)
# 	7856795 SNP locations read from file
# 	of those, 4909274 (62.48%) mapped to at least one gene
# Writing annotation to file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot
# 	for chromosome  1, 5 genes are empty (out of 2016)
# 	for chromosome  2, 2 genes are empty (out of 1226)
# 	for chromosome  4, 2 genes are empty (out of 745)
# 	for chromosome  5, 2 genes are empty (out of 856)
# 	for chromosome  9, 11 genes are empty (out of 775)
# 	for chromosome 10, 1 gene is empty (out of 723)
# 	for chromosome 15, 2 genes are empty (out of 586)
# 	for chromosome 16, 1 gene is empty (out of 817)
# 	for chromosome 21, 1 gene is empty (out of 215)
# 	for chromosome  X, 805 genes are empty (out of 805)
# 	for chromosome  Y, 47 genes are empty (out of 47)
# 	at least one SNP mapped to each of a total of 18548 genes (out of 19427)
#
#
# End time is 11:49:29, Sunday 14 Mar 2021 (elapsed: 00:00:13)
# # window_up = 50000
# # window_down = 50000
# 79501	1:19091:120008	rs200943160	rs2462492	rs114608975	rs6702460

# %%
# %%bash
# #Gene level analysis is performed using MAGMA, which compute gene-wise statistics taking into account physical distance and linkage disequilibrium (LD) between markers (de Leeuw et al. 2015).
# # All SNPs with MAF above 5% are used in these analyses, setting a distance threshold of 50kb, which usually ranges from 0 to 200kb
# # N: number of individuals
# for i in {1..22}
# do
# nohup /usr/lib/magma/magma  --batch $i chr --big-data --seed 1234 --genes-only --bfile /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed --gene-annot $path/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot  --pval $path/dataset.b37.imputed.dosage.maf.0.01.SNP.PVAL  N=496 --gene-model multi --out $path/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma &
# done
# Out:
# Welcome to MAGMA v1.06 (linux)
# Using flags:
# 	--batch 1 chr
# 	--big-data
# 	--seed 1234
# 	--genes-only
# 	--bfile /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed
# 	--gene-annot /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot
# 	--pval /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.SNP.PVAL N=496
# 	--gene-model multi
# 	--out /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma
#
# Start time is 11:49:29, Sunday 14 Mar 2021
#
# Loading PLINK-format data...
# Reading file /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed.fam... 496 individuals read
# Reading file /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed.bim (chromosome 1 only)... Welcome to MAGMA v1.06 (linux)
# Using flags:
# 	--batch 2 chr
# 	--big-data
# 	--seed 1234
# 	--genes-only
# 	--bfile /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed
# 	--gene-annot /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot
# 	--pval /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.SNP.PVAL N=496
# 	--gene-model multi
# 	--out /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma
#
# Start time is 11:49:29, Sunday 14 Mar 2021
#
# Loading PLINK-format data...
# Reading file /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed.fam... 496 individuals read
# Reading file /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed.bim (chromosome 2 only)... Welcome to MAGMA v1.06 (linux)
# Using flags:
# 	--batch 3 chr
# 	--big-data
# 	--seed 1234
# 	--genes-only
# 	--bfile /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed
# 	--gene-annot /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot
# 	--pval /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.SNP.PVAL N=496
# 	--gene-model multi
# 	--out /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma
#
# Start time is 11:49:29, Sunday 14 Mar 2021
#
# Welcome to MAGMA v1.06 (linux)
# Using flags:
# 	--batch 4 chr
# 	--big-data
# 	--seed 1234
# 	--genes-only
# 	--bfile /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed
# 	--gene-annot /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot
# 	--pval /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.SNP.PVAL N=496
# 	--gene-model multi
# 	--out /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma
#
# Start time is 11:49:29, Sunday 14 Mar 2021
#
# Loading PLINK-format data...
# Reading file /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed.fam... 496 individuals read
# Reading file /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed.bim (chromosome 3 only)... Loading PLINK-format data...
# Reading file /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed.fam... 496 individuals read
# Reading file /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed.bim (chromosome 4 only)... Welcome to MAGMA v1.06 (linux)
# Using flags:
# 	--batch 6 chr
# 	--big-data
# 	--seed 1234
# 	--genes-only
# 	--bfile /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed
# 	--gene-annot /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot
# 	--pval /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.SNP.PVAL N=496
# 	--gene-model multi
# 	--out /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma
#
# Start time is 11:49:29, Sunday 14 Mar 2021
#
# Loading PLINK-format data...
# Reading file /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed.fam... 496 individuals read
# Reading file /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed.bim (chromosome 6 only)... Welcome to MAGMA v1.06 (linux)
# Using flags:
# 	--batch 5 chr
# 	--big-data
# 	--seed 1234
# 	--genes-only
# 	--bfile /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed
# 	--gene-annot /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot
# 	--pval /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.SNP.PVAL N=496
# 	--gene-model multi
# 	--out /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma
#
# Start time is 11:49:29, Sunday 14 Mar 2021
#
# Loading PLINK-format data...
# Reading file /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed.fam... 496 individuals read
# Reading file /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed.bim (chromosome 5 only)... Welcome to MAGMA v1.06 (linux)
# Using flags:
# 	--batch 8 chr
# 	--big-data
# 	--seed 1234
# 	--genes-only
# 	--bfile /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed
# 	--gene-annot /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot
# 	--pval /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.SNP.PVAL N=496
# 	--gene-model multi
# 	--out /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma
#
# Start time is 11:49:29, Sunday 14 Mar 2021
#
# Loading PLINK-format data...
# Reading file /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed.fam... 496 individuals read
# Reading file /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed.bim (chromosome 8 only)... Welcome to MAGMA v1.06 (linux)
# Using flags:
# 	--batch 7 chr
# 	--big-data
# 	--seed 1234
# 	--genes-only
# 	--bfile /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed
# 	--gene-annot /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot
# 	--pval /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.SNP.PVAL N=496
# 	--gene-model multi
# 	--out /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma
#
# Start time is 11:49:29, Sunday 14 Mar 2021
#
# Loading PLINK-format data...
# Reading file /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed.fam... 496 individuals read
# Reading file /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed.bim (chromosome 7 only)... Welcome to MAGMA v1.06 (linux)
# Using flags:
# 	--batch 10 chr
# 	--big-data
# 	--seed 1234
# 	--genes-only
# 	--bfile /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed
# 	--gene-annot /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot
# 	--pval /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.SNP.PVAL N=496
# 	--gene-model multi
# 	--out /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma
#
# Start time is 11:49:29, Sunday 14 Mar 2021
#
# Loading PLINK-format data...
# Reading file /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed.fam... 496 individuals read
# Reading file /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed.bim (chromosome 10 only)... Welcome to MAGMA v1.06 (linux)
# Using flags:
# 	--batch 9 chr
# 	--big-data
# 	--seed 1234
# 	--genes-only
# 	--bfile /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed
# 	--gene-annot /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot
# 	--pval /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.SNP.PVAL N=496
# 	--gene-model multi
# 	--out /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma
#
# Start time is 11:49:29, Sunday 14 Mar 2021
#
# Loading PLINK-format data...
# Reading file /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed.fam... 496 individuals read
# Reading file /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed.bim (chromosome 9 only)... Welcome to MAGMA v1.06 (linux)
# Using flags:
# 	--batch 17 chr
# 	--big-data
# 	--seed 1234
# 	--genes-only
# 	--bfile /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed
# 	--gene-annot /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot
# 	--pval /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.SNP.PVAL N=496
# 	--gene-model multi
# 	--out /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma
#
# Start time is 11:49:29, Sunday 14 Mar 2021
#
# Loading PLINK-format data...
# Reading file /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed.fam... 496 individuals read
# Reading file /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed.bim (chromosome 17 only)... Welcome to MAGMA v1.06 (linux)
# Using flags:
# 	--batch 18 chr
# 	--big-data
# 	--seed 1234
# 	--genes-only
# 	--bfile /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed
# 	--gene-annot /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot
# 	--pval /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.SNP.PVAL N=496
# 	--gene-model multi
# 	--out /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma
#
# Start time is 11:49:29, Sunday 14 Mar 2021
#
# Loading PLINK-format data...
# Reading file /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed.fam... 496 individuals read
# Reading file /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed.bim (chromosome 18 only)... Welcome to MAGMA v1.06 (linux)
# Using flags:
# 	--batch 11 chr
# 	--big-data
# 	--seed 1234
# 	--genes-only
# 	--bfile /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed
# 	--gene-annot /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot
# 	--pval /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.SNP.PVAL N=496
# 	--gene-model multi
# 	--out /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma
#
# Start time is 11:49:29, Sunday 14 Mar 2021
#
# Loading PLINK-format data...
# Reading file /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed.fam... 496 individuals read
# Reading file /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed.bim (chromosome 11 only)... Welcome to MAGMA v1.06 (linux)
# Using flags:
# 	--batch 19 chr
# 	--big-data
# 	--seed 1234
# 	--genes-only
# 	--bfile /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed
# 	--gene-annot /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot
# 	--pval /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.SNP.PVAL N=496
# 	--gene-model multi
# 	--out /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma
#
# Start time is 11:49:29, Sunday 14 Mar 2021
#
# Loading PLINK-format data...
# Reading file /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed.fam... 496 individuals read
# Reading file /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed.bim (chromosome 19 only)... Welcome to MAGMA v1.06 (linux)
# Using flags:
# 	--batch 12 chr
# 	--big-data
# 	--seed 1234
# 	--genes-only
# 	--bfile /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed
# 	--gene-annot /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot
# 	--pval /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.SNP.PVAL N=496
# 	--gene-model multi
# 	--out /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma
#
# Start time is 11:49:29, Sunday 14 Mar 2021
#
# Loading PLINK-format data...
# Reading file /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed.fam... 496 individuals read
# Reading file /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed.bim (chromosome 12 only)... Welcome to MAGMA v1.06 (linux)
# Using flags:
# 	--batch 13 chr
# 	--big-data
# 	--seed 1234
# 	--genes-only
# 	--bfile /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed
# 	--gene-annot /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot
# 	--pval /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.SNP.PVAL N=496
# 	--gene-model multi
# 	--out /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma
#
# Start time is 11:49:29, Sunday 14 Mar 2021
#
# Loading PLINK-format data...
# Reading file /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed.fam... 496 individuals read
# Reading file /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed.bim (chromosome 13 only)... Welcome to MAGMA v1.06 (linux)
# Using flags:
# 	--batch 22 chr
# 	--big-data
# 	--seed 1234
# 	--genes-only
# 	--bfile /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed
# 	--gene-annot /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot
# 	--pval /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.SNP.PVAL N=496
# 	--gene-model multi
# 	--out /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma
#
# Start time is 11:49:29, Sunday 14 Mar 2021
#
# Loading PLINK-format data...
# Reading file /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed.fam... 496 individuals read
# Reading file /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed.bim (chromosome 22 only)... Welcome to MAGMA v1.06 (linux)
# Using flags:
# 	--batch 14 chr
# 	--big-data
# 	--seed 1234
# 	--genes-only
# 	--bfile /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed
# 	--gene-annot /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot
# 	--pval /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.SNP.PVAL N=496
# 	--gene-model multi
# 	--out /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma
#
# Start time is 11:49:29, Sunday 14 Mar 2021
#
# Loading PLINK-format data...
# Reading file /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed.fam... 496 individuals read
# Reading file /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed.bim (chromosome 14 only)... Welcome to MAGMA v1.06 (linux)
# Using flags:
# 	--batch 21 chr
# 	--big-data
# 	--seed 1234
# 	--genes-only
# 	--bfile /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed
# 	--gene-annot /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot
# 	--pval /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.SNP.PVAL N=496
# 	--gene-model multi
# 	--out /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma
#
# Start time is 11:49:29, Sunday 14 Mar 2021
#
# Loading PLINK-format data...
# Reading file /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed.fam... 496 individuals read
# Reading file /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed.bim (chromosome 21 only)... Welcome to MAGMA v1.06 (linux)
# Using flags:
# 	--batch 15 chr
# 	--big-data
# 	--seed 1234
# 	--genes-only
# 	--bfile /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed
# 	--gene-annot /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot
# 	--pval /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.SNP.PVAL N=496
# 	--gene-model multi
# 	--out /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma
#
# Start time is 11:49:29, Sunday 14 Mar 2021
#
# Loading PLINK-format data...
# Reading file /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed.fam... 496 individuals read
# Reading file /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed.bim (chromosome 15 only)... Welcome to MAGMA v1.06 (linux)
# Using flags:
# 	--batch 20 chr
# 	--big-data
# 	--seed 1234
# 	--genes-only
# 	--bfile /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed
# 	--gene-annot /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot
# 	--pval /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.SNP.PVAL N=496
# 	--gene-model multi
# 	--out /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma
#
# Start time is 11:49:29, Sunday 14 Mar 2021
#
# Loading PLINK-format data...
# Reading file /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed.fam... 496 individuals read
# Reading file /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed.bim (chromosome 20 only)... Welcome to MAGMA v1.06 (linux)
# Using flags:
# 	--batch 16 chr
# 	--big-data
# 	--seed 1234
# 	--genes-only
# 	--bfile /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed
# 	--gene-annot /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot
# 	--pval /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.SNP.PVAL N=496
# 	--gene-model multi
# 	--out /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma
#
# Start time is 11:49:29, Sunday 14 Mar 2021
#
# Loading PLINK-format data...
# Reading file /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed.fam... 496 individuals read
# Reading file /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed.bim (chromosome 16 only)... 7076087 SNPs read, of which 371410 used
# Preparing file /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed.bed...
#
# Reading SNP p-values from file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.SNP.PVAL...
# 	detected 2 variables in file
# 	using variable: SNP (SNP id)
# 	using variable: P (p-value)
# 7076087 SNPs read, of which 524714 used
# Preparing file /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed.bed...
#
# Reading SNP p-values from file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.SNP.PVAL...
# 	detected 2 variables in file
# 	using variable: SNP (SNP id)
# 	using variable: P (p-value)
# 7076087 SNPs read, of which 164227 used
# Preparing file /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed.bed...
#
# Reading SNP p-values from file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.SNP.PVAL...
# 	detected 2 variables in file
# 	using variable: SNP (SNP id)
# 	using variable: P (p-value)
# 7076087 SNPs read, of which 224452 used
# Preparing file /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed.bed...
#
# Reading SNP p-values from file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.SNP.PVAL...
# 	detected 2 variables in file
# 	using variable: SNP (SNP id)
# 	using variable: P (p-value)
# 7076087 SNPs read, of which 498385 used
# Preparing file /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed.bed...
#
# Reading SNP p-values from file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.SNP.PVAL...
# 	detected 2 variables in file
# 	using variable: SNP (SNP id)
# 	using variable: P (p-value)
# 7076087 SNPs read, of which 209209 used
# Preparing file /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed.bed...
#
# Reading SNP p-values from file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.SNP.PVAL...
# 	detected 2 variables in file
# 	using variable: SNP (SNP id)
# 	using variable: P (p-value)
# 7076087 SNPs read, of which 485255 used
# Preparing file /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed.bed...
#
# Reading SNP p-values from file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.SNP.PVAL...
# 	detected 2 variables in file
# 	using variable: SNP (SNP id)
# 	using variable: P (p-value)
# 7076087 SNPs read, of which 98123 used
# Preparing file /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed.bed...
#
# Reading SNP p-values from file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.SNP.PVAL...
# 	detected 2 variables in file
# 	using variable: SNP (SNP id)
# 	using variable: P (p-value)
# 7076087 SNPs read, of which 432041 used
# Preparing file /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed.bed...
#
# Reading SNP p-values from file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.SNP.PVAL...
# 	detected 2 variables in file
# 	using variable: SNP (SNP id)
# 	using variable: P (p-value)
# 7076087 SNPs read, of which 405260 used
# Preparing file /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed.bed...
#
# Reading SNP p-values from file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.SNP.PVAL...
# 	detected 2 variables in file
# 	using variable: SNP (SNP id)
# 	using variable: P (p-value)
# 7076087 SNPs read, of which 295895 used
# Preparing file /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed.bed...
#
# Reading SNP p-values from file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.SNP.PVAL...
# 	detected 2 variables in file
# 	using variable: SNP (SNP id)
# 	using variable: P (p-value)
# 7076087 SNPs read, of which 195795 used
# Preparing file /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed.bed...
#
# Reading SNP p-values from file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.SNP.PVAL...
# 	detected 2 variables in file
# 	using variable: SNP (SNP id)
# 	using variable: P (p-value)
# 7076087 SNPs read, of which 343970 used
# Preparing file /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed.bed...
#
# Reading SNP p-values from file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.SNP.PVAL...
# 	detected 2 variables in file
# 	using variable: SNP (SNP id)
# 	using variable: P (p-value)
# 7076087 SNPs read, of which 254900 used
# Preparing file /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed.bed...
#
# Reading SNP p-values from file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.SNP.PVAL...
# 	detected 2 variables in file
# 	using variable: SNP (SNP id)
# 	using variable: P (p-value)
# 7076087 SNPs read, of which 96709 used
# Preparing file /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed.bed...
#
# Reading SNP p-values from file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.SNP.PVAL...
# 	detected 2 variables in file
# 	using variable: SNP (SNP id)
# 	using variable: P (p-value)
# 7076087 SNPs read, of which 151312 used
# Preparing file /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed.bed...
#
# Reading SNP p-values from file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.SNP.PVAL...
# 	detected 2 variables in file
# 	using variable: SNP (SNP id)
# 	using variable: P (p-value)
# 7076087 SNPs read, of which 188159 used
# Preparing file /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed.bed...
#
# Reading SNP p-values from file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.SNP.PVAL...
# 	detected 2 variables in file
# 	using variable: SNP (SNP id)
# 	using variable: P (p-value)
# 7076087 SNPs read, of which 353501 used
# Preparing file /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed.bed...
#
# Reading SNP p-values from file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.SNP.PVAL...
# 	detected 2 variables in file
# 	using variable: SNP (SNP id)
# 	using variable: P (p-value)
# 7076087 SNPs read, of which 194819 used
# Preparing file /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed.bed...
#
# Reading SNP p-values from file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.SNP.PVAL...
# 	detected 2 variables in file
# 	using variable: SNP (SNP id)
# 	using variable: P (p-value)
# 7076087 SNPs read, of which 465189 used
# Preparing file /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed.bed...
#
# Reading SNP p-values from file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.SNP.PVAL...
# 	detected 2 variables in file
# 	using variable: SNP (SNP id)
# 	using variable: P (p-value)
# 7076087 SNPs read, of which 568940 used
# Preparing file /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed.bed...
#
# Reading SNP p-values from file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.SNP.PVAL...
# 	detected 2 variables in file
# 	using variable: SNP (SNP id)
# 	using variable: P (p-value)
# 7076087 SNPs read, of which 331587 used
# Preparing file /mnt/data/GWAS/output/build37/task2_QC/dataset.b37.QCed.bed...
#
# Reading SNP p-values from file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.SNP.PVAL...
# 	detected 2 variables in file
# 	using variable: SNP (SNP id)
# 	using variable: P (p-value)
# 	read 7856796 lines from file, containing valid SNP p-values for 73842 SNPs in data (0.9398% of lines, 76.35% of SNPs in data)
# Filtering phenotype/covariate missing values... 496 individuals remaining
#
# Loading gene annotation from file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot...
# 	read 7856796 lines from file, containing valid SNP p-values for 298990 SNPs in data (3.805% of lines, 80.5% of SNPs in data)
# Filtering phenotype/covariate missing values... 496 individuals remaining
#
# Loading gene annotation from file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot...
# 	442 gene definitions read from file
# 	found 439 genes containing SNPs in genotype data
#
# Starting gene analysis...
# 	using multi-model containing:
# 		SNPwise-mean
# 		SNPwise-top
# 	analysing chromosome 22, containing 439 genes
# 	WARNING: disabling 'big-data' mode, sample size is too small
# 	read 7856796 lines from file, containing valid SNP p-values for 121699 SNPs in data (1.549% of lines, 74.1% of SNPs in data)
# Filtering phenotype/covariate missing values... 496 individuals remaining
#
# Loading gene annotation from file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot...
# 	read 7856796 lines from file, containing valid SNP p-values for 410713 SNPs in data (5.227% of lines, 78.27% of SNPs in data)
# Filtering phenotype/covariate missing values... 496 individuals remaining
#
# Loading gene annotation from file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot...
# 	669 gene definitions read from file
# 	found 660 genes containing SNPs in genotype data
#
# 	read 7856796 lines from file, containing valid SNP p-values for 122373 SNPs in data (1.558% of lines, 80.87% of SNPs in data)
# Filtering phenotype/covariate missing values... 496 individuals remaining
#
# Loading gene annotation from file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot...
# 	read 7856796 lines from file, containing valid SNP p-values for 143235 SNPs in data (1.823% of lines, 76.12% of SNPs in data)
# Filtering phenotype/covariate missing values... 496 individuals remaining
#
# Loading gene annotation from file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot...
# 	read 7856796 lines from file, containing valid SNP p-values for 339856 SNPs in data (4.326% of lines, 78.66% of SNPs in data)
# Filtering phenotype/covariate missing values... 496 individuals remaining
#
# Loading gene annotation from file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot...
# Starting gene analysis...
# 	using multi-model containing:
# 		SNPwise-mean
# 		SNPwise-top
# 	analysing chromosome 8, containing 660 genes
# 	WARNING: disabling 'big-data' mode, sample size is too small
# 	1389 gene definitions read from file
# 	found 1388 genes containing SNPs in genotype data
#
# Starting gene analysis...
# 	using multi-model containing:
# 		SNPwise-mean
# 		SNPwise-top
# 	analysing chromosome 19, containing 1388 genes
# 	WARNING: disabling 'big-data' mode, sample size is too small
# 	854 gene definitions read from file
# 	found 854 genes containing SNPs in genotype data
#
# 	527 gene definitions read from file
# 	found 527 genes containing SNPs in genotype data
#
# Starting gene analysis...
# 	using multi-model containing:
# 		SNPwise-mean
# 		SNPwise-top
# 	analysing chromosome 5, containing 854 genes
# 	WARNING: disabling 'big-data' mode, sample size is too small
# Starting gene analysis...
# 	using multi-model containing:
# 		SNPwise-mean
# 		SNPwise-top
# 	analysing chromosome 20, containing 527 genes
# 	WARNING: disabling 'big-data' mode, sample size is too small
# 	read 7856796 lines from file, containing valid SNP p-values for 316130 SNPs in data (4.024% of lines, 78.01% of SNPs in data)
# 	read 7856796 lines from file, containing valid SNP p-values for 232834 SNPs in data (2.963% of lines, 78.69% of SNPs in data)
# Filtering phenotype/covariate missing values... 496 individuals remaining
#
# Loading gene annotation from file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot...
# 	read 7856796 lines from file, containing valid SNP p-values for 390688 SNPs in data (4.973% of lines, 78.39% of SNPs in data)
# Filtering phenotype/covariate missing values... 496 individuals remaining
#
# Loading gene annotation from file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot...
# 	read 7856796 lines from file, containing valid SNP p-values for 78155 SNPs in data (0.9947% of lines, 79.65% of SNPs in data)
# Filtering phenotype/covariate missing values... 496 individuals remaining
#
# Loading gene annotation from file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot...
# 	read 7856796 lines from file, containing valid SNP p-values for 152746 SNPs in data (1.944% of lines, 78.01% of SNPs in data)
# Filtering phenotype/covariate missing values... 496 individuals remaining
#
# Loading gene annotation from file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot...
# Filtering phenotype/covariate missing values... 496 individuals remaining
#
# Loading gene annotation from file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot...
# 	1147 gene definitions read from file
# 	found 1141 genes containing SNPs in genotype data
#
# 	read 7856796 lines from file, containing valid SNP p-values for 155600 SNPs in data (1.98% of lines, 79.87% of SNPs in data)
# 	read 7856796 lines from file, containing valid SNP p-values for 166396 SNPs in data (2.118% of lines, 79.54% of SNPs in data)
# Filtering phenotype/covariate missing values... 496 individuals remaining
#
# Loading gene annotation from file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot...
# Starting gene analysis...
# 	using multi-model containing:
# 		SNPwise-mean
# 		SNPwise-top
# 	analysing chromosome 17, containing 1141 genes
# 	WARNING: disabling 'big-data' mode, sample size is too small
# Filtering phenotype/covariate missing values... 496 individuals remaining
#
# Loading gene annotation from file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot...
# 	214 gene definitions read from file
# 	found 214 genes containing SNPs in genotype data
#
# Starting gene analysis...
# 	using multi-model containing:
# 		SNPwise-mean
# 		SNPwise-top
# 	analysing chromosome 21, containing 214 genes
# 	WARNING: disabling 'big-data' mode, sample size is too small
# 	2011 gene definitions read from file
# 	found 2002 genes containing SNPs in genotype data
#
# 	read 7856796 lines from file, containing valid SNP p-values for 176252 SNPs in data (2.243% of lines, 78.53% of SNPs in data)
# Filtering phenotype/covariate missing values... 496 individuals remaining
#
# Loading gene annotation from file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot...
# 	584 gene definitions read from file
# 	found 573 genes containing SNPs in genotype data
#
# 	271 gene definitions read from file
# 	found 271 genes containing SNPs in genotype data
#
# Starting gene analysis...
# 	using multi-model containing:
# 		SNPwise-mean
# 		SNPwise-top
# 	analysing chromosome 15, containing 573 genes
# 	WARNING: disabling 'big-data' mode, sample size is too small
# Starting gene analysis...
# 	using multi-model containing:
# 		SNPwise-mean
# 		SNPwise-top
# 	analysing chromosome 1, containing 2002 genes
# 	WARNING: disabling 'big-data' mode, sample size is too small
# 	764 gene definitions read from file
# 	found 759 genes containing SNPs in genotype data
#
# Starting gene analysis...
# 	using multi-model containing:
# 		SNPwise-mean
# 		SNPwise-top
# 	analysing chromosome 18, containing 271 genes
# 	WARNING: disabling 'big-data' mode, sample size is too small
# 	906 gene definitions read from file
# 	found 901 genes containing SNPs in genotype data
#
# Starting gene analysis...
# 	using multi-model containing:
# 		SNPwise-mean
# 		SNPwise-top
# 	analysing chromosome 9, containing 759 genes
# 	WARNING: disabling 'big-data' mode, sample size is too small
# 	read 7856796 lines from file, containing valid SNP p-values for 202513 SNPs in data (2.578% of lines, 79.45% of SNPs in data)
# 	743 gene definitions read from file
# 	found 731 genes containing SNPs in genotype data
#
# Filtering phenotype/covariate missing values... 496 individuals remaining
#
# Loading gene annotation from file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot...
# 	816 gene definitions read from file
# 	found 810 genes containing SNPs in genotype data
#
# 	595 gene definitions read from file
# 	found 594 genes containing SNPs in genotype data
#
# Starting gene analysis...
# 	using multi-model containing:
# 		SNPwise-mean
# 		SNPwise-top
# 	analysing chromosome 7, containing 901 genes
# 	WARNING: disabling 'big-data' mode, sample size is too small
# Starting gene analysis...
# 	using multi-model containing:
# 		SNPwise-mean
# 		SNPwise-top
# 	analysing chromosome 16, containing 810 genes
# 	WARNING: disabling 'big-data' mode, sample size is too small
# Starting gene analysis...
# 	using multi-model containing:
# 		SNPwise-mean
# 		SNPwise-top
# 	analysing chromosome 14, containing 594 genes
# 	WARNING: disabling 'big-data' mode, sample size is too small
# Starting gene analysis...
# 	using multi-model containing:
# 		SNPwise-mean
# 		SNPwise-top
# 	analysing chromosome 4, containing 731 genes
# 	WARNING: disabling 'big-data' mode, sample size is too small
# 	read 7856796 lines from file, containing valid SNP p-values for 278923 SNPs in data (3.55% of lines, 78.9% of SNPs in data)
# Filtering phenotype/covariate missing values... 496 individuals remaining
#
# Loading gene annotation from file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot...
# 	320 gene definitions read from file
# 	found 320 genes containing SNPs in genotype data
#
# 	read 7856796 lines from file, containing valid SNP p-values for 271545 SNPs in data (3.456% of lines, 78.94% of SNPs in data)
# Filtering phenotype/covariate missing values... 496 individuals remaining
#
# Loading gene annotation from file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot...
# 	read 7856796 lines from file, containing valid SNP p-values for 450446 SNPs in data (5.733% of lines, 79.17% of SNPs in data)
# Starting gene analysis...
# 	using multi-model containing:
# 		SNPwise-mean
# 		SNPwise-top
# 	analysing chromosome 13, containing 320 genes
# 	WARNING: disabling 'big-data' mode, sample size is too small
# Filtering phenotype/covariate missing values... 496 individuals remaining
#
# Loading gene annotation from file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot...
# 	722 gene definitions read from file
# 	found 720 genes containing SNPs in genotype data
#
# 	read 7856796 lines from file, containing valid SNP p-values for 259485 SNPs in data (3.303% of lines, 78.26% of SNPs in data)
# Filtering phenotype/covariate missing values... 496 individuals remaining
#
# Loading gene annotation from file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot...
# 	read 7856796 lines from file, containing valid SNP p-values for 384488 SNPs in data (4.894% of lines, 79.23% of SNPs in data)
# Starting gene analysis...
# 	using multi-model containing:
# 		SNPwise-mean
# 		SNPwise-top
# 	analysing chromosome 10, containing 720 genes
# 	WARNING: disabling 'big-data' mode, sample size is too small
# Filtering phenotype/covariate missing values... 496 individuals remaining
#
# Loading gene annotation from file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot...
# 	1275 gene definitions read from file
# 	found 1275 genes containing SNPs in genotype data
#
# Starting gene analysis...
# 	using multi-model containing:
# 		SNPwise-mean
# 		SNPwise-top
# 	analysing chromosome 11, containing 1275 genes
# 	WARNING: disabling 'big-data' mode, sample size is too small
# 	1009 gene definitions read from file
# 	found 1009 genes containing SNPs in genotype data
#
# 	1224 gene definitions read from file
# 	found 1220 genes containing SNPs in genotype data
#
# Starting gene analysis...
# 	using multi-model containing:
# 		SNPwise-mean
# 		SNPwise-top
# 	analysing chromosome 12, containing 1009 genes
# 	WARNING: disabling 'big-data' mode, sample size is too small
# Starting gene analysis...
# 	using multi-model containing:
# 		SNPwise-mean
# 		SNPwise-top
# 	analysing chromosome 2, containing 1220 genes
# 	WARNING: disabling 'big-data' mode, sample size is too small
# 	read 7856796 lines from file, containing valid SNP p-values for 359532 SNPs in data (4.576% of lines, 77.29% of SNPs in data)
# Filtering phenotype/covariate missing values... 496 individuals remaining
#
# Loading gene annotation from file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot...
# 	1050 gene definitions read from file
# 	found 1050 genes containing SNPs in genotype data
#
# Starting gene analysis...
# 	using multi-model containing:
# 		SNPwise-mean
# 		SNPwise-top
# 	analysing chromosome 3, containing 1050 genes
# 	WARNING: disabling 'big-data' mode, sample size is too small
# 	1016 gene definitions read from file
# 	found 1016 genes containing SNPs in genotype data
#
# Starting gene analysis... )
# 	using multi-model containing:
# 		SNPwise-mean
# 		SNPwise-top
# 	analysing chromosome 6, containing 1016 genes
# 	WARNING: disabling 'big-data' mode, sample size is too small
# 	writing gene analysis results to file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch21_chr.genes.out
# 	processed genes: 229 (18%)
#
# End time is 11:58:48, Sunday 14 Mar 2021 (elapsed: 00:09:19)
# 	writing gene analysis results to file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch18_chr.genes.out
#
#
# End time is 12:02:03, Sunday 14 Mar 2021 (elapsed: 00:12:34)
# 	writing gene analysis results to file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch22_chr.genes.out
#
#
# End time is 12:04:21, Sunday 14 Mar 2021 (elapsed: 00:14:52)
# 	writing gene analysis results to file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch13_chr.genes.out
#
#
# End time is 12:05:20, Sunday 14 Mar 2021 (elapsed: 00:15:51)
# 	writing gene analysis results to file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch20_chr.genes.out
#
#
# End time is 12:07:48, Sunday 14 Mar 2021 (elapsed: 00:18:19)
# 	writing gene analysis results to file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch14_chr.genes.out
#
#
# End time is 12:10:12, Sunday 14 Mar 2021 (elapsed: 00:20:43)
# 	writing gene analysis results to file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch15_chr.genes.out
#
#
# End time is 12:11:08, Sunday 14 Mar 2021 (elapsed: 00:21:39)
# 	writing gene analysis results to file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch16_chr.genes.out
#
#
# End time is 12:12:59, Sunday 14 Mar 2021 (elapsed: 00:23:30)
# 	writing gene analysis results to file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch9_chr.genes.out
#
#
# End time is 12:15:13, Sunday 14 Mar 2021 (elapsed: 00:25:44)
# 	writing gene analysis results to file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch8_chr.genes.out
#
# 	processed genes: 744 (70.9%)
# End time is 12:15:23, Sunday 14 Mar 2021 (elapsed: 00:25:54)
# 	writing gene analysis results to file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch17_chr.genes.out
#
#
# End time is 12:15:44, Sunday 14 Mar 2021 (elapsed: 00:26:15)
# 	writing gene analysis results to file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch10_chr.genes.out
#
#
# End time is 12:16:13, Sunday 14 Mar 2021 (elapsed: 00:26:44)
# 	writing gene analysis results to file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch5_chr.genes.out
#
#
# End time is 12:16:20, Sunday 14 Mar 2021 (elapsed: 00:26:51)
# 	writing gene analysis results to file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch4_chr.genes.out
#
#
# End time is 12:16:25, Sunday 14 Mar 2021 (elapsed: 00:26:56)
# 	writing gene analysis results to file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch12_chr.genes.out
#
#
# End time is 12:17:33, Sunday 14 Mar 2021 (elapsed: 00:28:04)
# 	writing gene analysis results to file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch7_chr.genes.out
#
#
# End time is 12:17:48, Sunday 14 Mar 2021 (elapsed: 00:28:19)
# 	writing gene analysis results to file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch6_chr.genes.out
#
#
# End time is 12:20:11, Sunday 14 Mar 2021 (elapsed: 00:30:42)
# 	writing gene analysis results to file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch3_chr.genes.out
#
#
# End time is 12:20:33, Sunday 14 Mar 2021 (elapsed: 00:31:04)
# 	writing gene analysis results to file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch11_chr.genes.out
#
#
# End time is 12:20:52, Sunday 14 Mar 2021 (elapsed: 00:31:23)
# 	writing gene analysis results to file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch2_chr.genes.out
#
#
# End time is 12:21:01, Sunday 14 Mar 2021 (elapsed: 00:31:32)
# 	writing gene analysis results to file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch19_chr.genes.out
#
#
# End time is 12:21:01, Sunday 14 Mar 2021 (elapsed: 00:31:32)
# 	writing gene analysis results to file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch1_chr.genes.out
#
#
# End time is 12:23:27, Sunday 14 Mar 2021 (elapsed: 00:33:58)

# %%
# %%bash
# #merge batches
# #/usr/lib/magma/magma
# magma --merge $path/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma --out $path/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma
# head $path/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.genes.out
# Out:
# Welcome to MAGMA v1.06 (linux)
# Using flags:
# 	--merge /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma
# 	--out /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma
#
# Start time is 12:23:27, Sunday 14 Mar 2021
#
# Merging gene results files with prefix '/mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma'...
# 	WARNING: found only 0 .genes.raw batch files for chromosomes 1-22
# Reading file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch1_chr.genes.out...
# 	2002 genes read from file
# Reading file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch2_chr.genes.out...
# 	1220 genes read from file
# Reading file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch3_chr.genes.out...
# 	1050 genes read from file
# Reading file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch4_chr.genes.out...
# 	731 genes read from file
# Reading file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch5_chr.genes.out...
# 	854 genes read from file
# Reading file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch6_chr.genes.out...
# 	1016 genes read from file
# Reading file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch7_chr.genes.out...
# 	901 genes read from file
# Reading file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch8_chr.genes.out...
# 	660 genes read from file
# Reading file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch9_chr.genes.out...
# 	759 genes read from file
# Reading file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch10_chr.genes.out...
# 	720 genes read from file
# Reading file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch11_chr.genes.out...
# 	1275 genes read from file
# Reading file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch12_chr.genes.out...
# 	1009 genes read from file
# Reading file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch13_chr.genes.out...
# 	320 genes read from file
# Reading file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch14_chr.genes.out...
# 	594 genes read from file
# Reading file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch15_chr.genes.out...
# 	573 genes read from file
# Reading file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch16_chr.genes.out...
# 	810 genes read from file
# Reading file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch17_chr.genes.out...
# 	1141 genes read from file
# Reading file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch18_chr.genes.out...
# 	271 genes read from file
# Reading file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch19_chr.genes.out...
# 	1388 genes read from file
# Reading file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch20_chr.genes.out...
# 	527 genes read from file
# Reading file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch21_chr.genes.out...
# 	214 genes read from file
# Reading file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch22_chr.genes.out...
# 	439 genes read from file
# Writing merged gene analysis results to file /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.genes.out
#
#
# End time is 12:23:27, Sunday 14 Mar 2021 (elapsed: 00:00:00)
# GENE       CHR      START       STOP  NSNPS  NPARAM    N        ZSTAT      P_JOINT  P_SNPWISE_MEAN  P_SNPWISE_TOP1
# 79501        1      19091     120008      1       1  496      -1.4684        0.929           0.929           0.929
# 148398       1     809993     929961    186      30  496     -0.61238      0.72986         0.73539         0.62993
# 26155        1     829583     944679    213      31  496     -0.65743      0.74455         0.76571         0.63687
# 339451       1     845967     951099    182      29  496     -0.73459       0.7687         0.74982         0.69474
# 84069        1     851872     960488    181      29  496     -0.86454      0.80635         0.81309         0.70204
# 84808        1     860579     967473    169      27  496     -0.82834      0.79626         0.79972         0.69029
# 57801        1     884342     986608    183      24  496     -0.68288      0.75266         0.79127         0.63263
# 9636         1     898847     999920    192      26  496     -0.83035      0.79683         0.82944         0.67171
# 375790       1     905503    1041499    277      28  496      -1.5092      0.93438         0.92836         0.88454

# %%
# %%bash
# sort -gk10,10 $path/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.genes.out >$path/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.genes.out.sorted
# head $path/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.genes.out.sorted
# Out:
# GENE       CHR      START       STOP  NSNPS  NPARAM    N        ZSTAT      P_JOINT  P_SNPWISE_MEAN  P_SNPWISE_TOP1
# 11214       15   85873818   86342589   1212      32  496       4.1297   1.8165e-05      9.2671e-06      0.00077629
# 64410       15   86252557   86388189    508      38  496       4.1298   1.8151e-05      2.5588e-05      0.00024736
# 343413       1  159720282  159836047    235      41  496       3.7093   0.00010392      6.7899e-05       0.0034542
# 134111       5    6387460    6546834    386      47  496       3.4649   0.00026519      6.8813e-05        0.012499
# 1053        14   23536515   23638820    147      28  496       3.4645   0.00026563      0.00010603       0.0079492
# 56833        1  159746440  159857282    237      37  496       3.7065   0.00010508      0.00010668       0.0035125
# 284677       1  159754264  159875544    260      33  496       3.5985   0.00016002      0.00012396       0.0035435
# 8698        19    3128250    3230335    395      50  496       2.8686    0.0020613      0.00017936        0.063752
# 10090        6  149018063  149448126   1001      83  496       3.2994   0.00048447      0.00017961         0.01721

# %%
# %%R
# # Annotate genes using the reference file NCBI37.3.gene.loc
# magma<-read.table("/mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.genes.out.sorted", header=TRUE)
# genes<-read.table("/mnt/data/GWAS/ref_files/NCBI37.3.gene.loc")
# colnames(genes) <- c("GENE","CHR","START","STOP","STRAND","HUGO")
#
# magma_merged<-merge(magma,genes, by="GENE")
# magma_merged <- magma_merged[order(magma_merged$P_SNPWISE_MEAN), ]
# magma_rank<-rank(magma_merged[,10],na.last = "keep", ties.method = "min")
# magma_ranked=cbind(magma_rank, magma_merged)
#
# write.table(magma_ranked, "/mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.genes.out.sorted.annot", quote=FALSE, sep="\t", row.names = FALSE)

# %%
# %%R
# magma<-read.table("/mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.genes.out.sorted", header=TRUE)
# head(magma)
# Out:
#     GENE CHR     START      STOP NSNPS NPARAM   N  ZSTAT    P_JOINT
# 1  11214  15  85873818  86342589  1212     32 496 4.1297 1.8165e-05
# 2  64410  15  86252557  86388189   508     38 496 4.1298 1.8151e-05
# 3 343413   1 159720282 159836047   235     41 496 3.7093 1.0392e-04
# 4 134111   5   6387460   6546834   386     47 496 3.4649 2.6519e-04
# 5   1053  14  23536515  23638820   147     28 496 3.4645 2.6563e-04
# 6  56833   1 159746440 159857282   237     37 496 3.7065 1.0508e-04
#   P_SNPWISE_MEAN P_SNPWISE_TOP1
# 1     9.2671e-06     0.00077629
# 2     2.5588e-05     0.00024736
# 3     6.7899e-05     0.00345420
# 4     6.8813e-05     0.01249900
# 5     1.0603e-04     0.00794920
# 6     1.0668e-04     0.00351250

# %%
# %%R
# genes<-read.table("/mnt/data/GWAS/ref_files/NCBI37.3.gene.loc")
# colnames(genes) <- c("GENE","CHR","START","STOP","STRAND","HUGO")
# head(genes)
# Out:
#        GENE CHR  START   STOP STRAND         HUGO
# 1     79501   1  69091  70008      +        OR4F5
# 2 100996442   1 142447 174392      - LOC100996442
# 3    729759   1 367659 368597      +       OR4F29
# 4     81399   1 621096 622034      -       OR4F16
# 5    148398   1 859993 879961      +       SAMD11
# 6     26155   1 879583 894679      -        NOC2L

# %%
# %%bash
# head /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.genes.out.sorted.annot
# tail /mnt/data/GWAS/output/build37/task6_genewise/dataset.b37.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.genes.out.sorted.annot
# Out:
# magma_rank	GENE	CHR.x	START.x	STOP.x	NSNPS	NPARAM	N	ZSTAT	P_JOINT	P_SNPWISE_MEAN	P_SNPWISE_TOP1	CHR.y	START.y	STOP.y	STRAND	HUGO
# 1	11214	15	85873818	86342589	1212	32	496	4.1297	1.8165e-05	9.2671e-06	0.00077629	15	85923818	86292589	+	AKAP13
# 2	64410	15	86252557	86388189	508	38	496	4.1298	1.8151e-05	2.5588e-05	0.00024736	15	86302557	86338189	-	KLHL25
# 3	343413	1	159720282	159836047	235	41	496	3.7093	0.00010392	6.7899e-05	0.0034542	1	159770282	159786047	+	FCRL6
# 4	134111	5	6387460	6546834	386	47	496	3.4649	0.00026519	6.8813e-05	0.012499	5	6437460	6496834	+	UBE2QL1
# 5	1053	14	23536515	23638820	147	28	496	3.4645	0.00026563	0.00010603	0.0079492	14	23586515	23588820	-	CEBPE
# 6	56833	1	159746440	159857282	237	37	496	3.7065	0.00010508	0.00010668	0.0035125	1	159796440	159807282	+	SLAMF8
# 7	284677	1	159754264	159875544	260	33	496	3.5985	0.00016002	0.00012396	0.0035435	1	159804264	159825544	-	C1orf204
# 8	8698	19	3128250	3230335	395	50	496	2.8686	0.0020613	0.00017936	0.063752	19	3178250	3180335	+	S1PR4
# 9	10090	6	149018063	149448126	1001	83	496	3.2994	0.00048447	0.00017961	0.01721	6	149068063	149398126	+	UST
# 18465	7476	3	13810082	13971618	338	43	496	-1.7793	0.96241	0.993	0.86559	3	13860082	13921618	-	WNT7A
# 18466	51617	5	173422607	173586182	277	29	496	-2.6862	0.99639	0.99304	0.99017	5	173472607	173536182	+	HMP19
# 18467	55773	3	99929661	100094096	178	16	496	-1.7151	0.95684	0.9932	0.87006	3	99979661	100044096	+	TBC1D23
# 18468	124923	17	26884799	26991377	29	5	496	-2.0588	0.98024	0.99368	0.94421	17	26934799	26941377	-	SGK494
# 18469	56954	3	100003483	100125844	118	15	496	-1.1783	0.88065	0.99399	0.74384	3	100053483	100075844	+	NIT2
# 18470	26664	19	14859943	14996188	421	40	496	-1.7973	0.96386	0.99412	0.8927	19	14909943	14946188	-	OR7C1
# 18471	50515	12	104800692	105205792	974	95	496	-0.46072	0.6775	0.99434	0.37459	12	104850692	105155792	+	CHST11
# 18472	10252	4	124267946	124374915	194	35	496	-2.7879	0.99735	0.99619	0.98737	4	124317946	124324915	+	SPRY1
# 18473	58499	9	109572469	109825525	292	31	496	-1.825	0.966	0.99759	0.88653	9	109622469	109775525	+	ZNF462
# 18474	2890	5	152820084	153243429	1085	49	496	-1.8282	0.96624	0.99837	0.87223	5	152870084	153193429	+	GRIA1
