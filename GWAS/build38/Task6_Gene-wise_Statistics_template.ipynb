# %% [markdown]
# # Task 6 Gene-wise statistics (MAGMA)
#
# In gene analysis, genetic marker data is aggregated to the level of whole genes, testing the joint association of all markers in the gene with the phenotype. Similarly, in gene-set analysis individual genes are aggregated to groups of genes sharing certain biological, functional or other characteristics.
#
# This is done using MAGMA[1]. The gene-set analysis is divided into two distinct and largely independent parts. In the first part a gene analysis is performed to quantify the degree of association each gene has with the phenotype. In addition the correlations between genes are estimated. These correlations reflect the LD between genes, and are needed in order to compensate for the dependencies between genes during the gene-set analysis. The gene p-values and gene correlation matrix are then used in the second part to perform the actual gene-set analysis.
#
#
# [1] de Leeuw CA, Mooij JM, Heskes T, Posthuma D. MAGMA: generalized gene-set analysis of GWAS data. PLoS computational biology. https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4401657/. Published April 17, 2015. Accessed August 18, 2020.

# %%
# %load_ext rpy2.ipython
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython

# %%
import os

# Create directories for the output files
path="/mnt/data/GWAS/output/build38/task6_genewise"
if not os.path.exists(path):
    os.makedirs(path)

# %%
# %env path=/mnt/data/GWAS/output/build38/task6_genewise
# %env task4path= /mnt/data/GWAS/output/build38/task4_assoc
# Out:
# env: path=/mnt/data/GWAS/output/build38/task6_genewise
# env: task4path=/mnt/data/GWAS/output/build38/task4_assoc

# %% [markdown]
# **Filter out low frequency SNPs (MAF<0.01 in this example) for MAGMA**

# %%
# %%bash
# awk '{OFS="\t"; if($6>0.01 && $6<0.99) print $0}' | sed 's/ /\t/g' $task4path/dataset.b38.imputed.assoc.dosage.clean.rs.200kb.annot > $path/dataset.b38.imputed.assoc.dosage.clean.rs.200kb.annot.maf.0.01
# wc $path/dataset.b38.imputed.assoc.dosage.clean.rs.200kb.annot.maf.0.01

# %%
# %%bash
# wc $path/dataset.b38.imputed.assoc.dosage.clean.rs.200kb.annot.maf.0.01
# wc $task4path/dataset.b38.imputed.assoc.dosage.clean.rs.200kb.annot
# Out:
#    8976887  107722644 1254477752 /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.assoc.dosage.clean.rs.200kb.annot.maf.0.01
#    8976887  107722644 1254477752 /mnt/data/GWAS/output/build38/task4_assoc/dataset.b38.imputed.assoc.dosage.clean.rs.200kb.annot

# %%
# %%bash
# head $path/dataset.b38.imputed.assoc.dosage.clean.rs.200kb.annot.maf.0.01
# Out:
# CHR	BP	SNP	A1	A2	FRQ	INFO	OR	SE	P	RS	ANNOT
# 10	100000235	10:100000235:C:T	C	T	0.2982	0.7959	0.6679	0.3084	0.1906	rs11596870	ABCC2(+148kb)|CHUK(-188.1kb)|CPN1(-42.07kb)|DNMBP(0)|DNMBP-AS1(+41.24kb)|ERLIN1(-149.9kb)
# 10	100000943	10:100000943:G:A	G	A	0.0929	0.7945	1.2681	0.5058	0.6387	rs11190359	ABCC2(+148.8kb)|CHUK(-187.4kb)|CPN1(-41.36kb)|DNMBP(0)|DNMBP-AS1(+41.94kb)|ERLIN1(-149.1kb)
# 10	100000979	10:100000979:T:C	T	C	0.0504	0.7881	1.7337	0.7499	0.4631	rs11190360	ABCC2(+148.8kb)|CHUK(-187.4kb)|CPN1(-41.33kb)|DNMBP(0)|DNMBP-AS1(+41.98kb)|ERLIN1(-149.1kb)
# 10	100002012	10:100002012:T:C	T	C	0.0374	0.8215	1.0097	0.6786	0.9886	rs11190362	ABCC2(+149.8kb)|CHUK(-186.4kb)|CPN1(-40.3kb)|DNMBP(0)|DNMBP-AS1(+43.01kb)|ERLIN1(-148.1kb)
# 10	100002038	10:100002038:G:A	G	A	0.0102	0.8861	3.051	1.3529	0.4097	rs192480913	ABCC2(+149.8kb)|CHUK(-186.3kb)|CPN1(-40.27kb)|DNMBP(0)|DNMBP-AS1(+43.04kb)|ERLIN1(-148.1kb)
# 10	100002300	10:100002300:GA:G	GA	G	0.0374	0.8216	1.0082	0.6788	0.9904	rs111354488	ABCC2(+150.1kb)|CHUK(-186.1kb)|CPN1(-40.01kb)|DNMBP(0)|DNMBP-AS1(+43.3kb)|ERLIN1(-147.8kb)
# 10	100002330	10:100002330:AAAAG:A	AAAAG	A	0.0647	0.8095	1.3697	0.6481	0.6274	NA	ABCC2(+150.1kb)|CHUK(-186kb)|CPN1(-39.98kb)|DNMBP(0)|DNMBP-AS1(+43.33kb)|ERLIN1(-147.8kb)
# 10	100002628	10:100002628:A:C	A	C	0.4467	0.8605	0.7322	0.2868	0.2771	rs11190363	ABCC2(+150.4kb)|CHUK(-185.7kb)|CPN1(-39.68kb)|DNMBP(0)|DNMBP-AS1(+43.63kb)|ERLIN1(-147.5kb)
# 10	100002875	10:100002875:A:G	A	G	0.0648	0.8118	1.3222	0.6435	0.6642	rs7894103	ABCC2(+150.7kb)|CHUK(-185.5kb)|CPN1(-39.43kb)|DNMBP(0)|DNMBP-AS1(+43.88kb)|ERLIN1(-147.2kb)

# %%
# %%bash
# # Generate  *.SNP.LOC (SNP, CHR,BP) and *.SNP.VAL files
#
# awk 'BEGIN{OFS="\t";print "SNP","CHR","BP"};{OFS="\t"; if(NR>1)  print $11,$1,$2}' $path/dataset.b38.imputed.assoc.dosage.clean.rs.200kb.annot.maf.0.01 > $path/dataset.b38.imputed.dosage.maf.0.01.SNP.LOC
# awk 'BEGIN{OFS="\t";print "SNP","P"};{OFS="\t"; if(NR>1) print $11,$10}' $path/dataset.b38.imputed.assoc.dosage.clean.rs.200kb.annot.maf.0.01 | sed 's/e/E/g' > $path/dataset.b38.imputed.dosage.maf.0.01.SNP.PVAL
#
# head -3 $path/dataset.b38.imputed.dosage.maf.0.01.SNP.LOC
# head -3  $path/dataset.b38.imputed.dosage.maf.0.01.SNP.PVAL
# Out:
# SNP	CHR	BP
# rs11596870	10	100000235
# rs11190359	10	100000943
# SNP	P
# rs11596870	0.1906
# rs11190359	0.6387

# %%
# %%bash
# # Annotate SNPS to genes in 50Kb; this parameter is not fixed, usually ranging from 0 to 500Kb. You cn modify this distance with the window parameter
# /usr/lib/magma/magma --annotate window=50,50 --snp-loc $path/dataset.b38.imputed.dosage.maf.0.01.SNP.LOC --gene-loc /mnt/data/GWAS/ref_files/build38/NCBI38.gene.loc --out $path/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb
# head -3 $path/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot
# Out:
# Welcome to MAGMA v1.06 (linux)
# Using flags:
# 	--annotate window=50,50
# 	--snp-loc /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.SNP.LOC
# 	--gene-loc /mnt/data/GWAS/ref_files/build38/NCBI38.gene.loc
# 	--out /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb
#
# Start time is 14:44:20, Saturday 06 Mar 2021
#
# Starting annotation...
# Reading gene locations from file /mnt/data/GWAS/ref_files/build38/NCBI38.gene.loc...
# 	adding window: 50000bp
# 	20137 gene locations read from file
# 	chromosome  1: 2097 genes
# 	chromosome  2: 1285 genes
# 	chromosome  3: 1078 genes
# 	chromosome  4: 765 genes
# 	chromosome  5: 886 genes
# 	chromosome  6: 1053 genes
# 	chromosome  7: 942 genes
# 	chromosome  8: 691 genes
# 	chromosome  9: 803 genes
# 	chromosome 10: 748 genes
# 	chromosome 11: 1299 genes
# 	chromosome 12: 1032 genes
# 	chromosome 13: 341 genes
# 	chromosome 14: 613 genes
# 	chromosome 15: 616 genes
# 	chromosome 16: 865 genes
# 	chromosome 17: 1197 genes
# 	chromosome 18: 283 genes
# 	chromosome 19: 1423 genes
# 	chromosome 20: 540 genes
# 	chromosome 21: 246 genes
# 	chromosome 22: 461 genes
# 	chromosome  X: 825 genes
# 	chromosome  Y: 48 genes
# Reading SNP locations from file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.SNP.LOC...
# 	WARNING: on line 1, chromosome code 'CHR' not recognised; skipping SNP (ID = SNP)
# 	8976886 SNP locations read from file
# 	of those, 5701055 (63.51%) mapped to at least one gene
# Writing annotation to file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot
# 	for chromosome  1, 10 genes are empty (out of 2097)
# 	for chromosome  2, 1 gene is empty (out of 1285)
# 	for chromosome  4, 2 genes are empty (out of 765)
# 	for chromosome  5, 3 genes are empty (out of 886)
# 	for chromosome  8, 12 genes are empty (out of 691)
# 	for chromosome  9, 26 genes are empty (out of 803)
# 	for chromosome 14, 7 genes are empty (out of 613)
# 	for chromosome 15, 13 genes are empty (out of 616)
# 	for chromosome 16, 5 genes are empty (out of 865)
# 	for chromosome 20, 3 genes are empty (out of 540)
# 	for chromosome 21, 22 genes are empty (out of 246)
# 	for chromosome 22, 2 genes are empty (out of 461)
# 	for chromosome  X, 825 genes are empty (out of 825)
# 	for chromosome  Y, 48 genes are empty (out of 48)
# 	at least one SNP mapped to each of a total of 19158 genes (out of 20137)
#
#
# End time is 14:44:34, Saturday 06 Mar 2021 (elapsed: 00:00:14)
# # window_up = 50000
# # window_down = 50000
# 81399	1:635716:736654	NA	NA	NA	NA	NA	rs151190501	rs61769339	NA	NA	NA	rs201221815	NA

# %%
# %%bash
# #Gene level analysis is performed using MAGMA, which compute gene-wise statistics taking into account physical distance and linkage disequilibrium (LD) between markers (de Leeuw et al. 2015).
# # All SNPs with MAF above 1% are used in these analyses, setting a distance threshold of 50kb. N is the number of individuals
# for i in {1..22}
# do
# nohup /usr/lib/magma/magma  --batch $i chr --big-data --seed 1234 --genes-only --bfile /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed --gene-annot $path/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot  --pval $path/dataset.b38.imputed.dosage.maf.0.01.SNP.PVAL  N=495 --gene-model multi --out $path/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma &
# done
# Out:
# Welcome to MAGMA v1.06 (linux)
# Using flags:
# 	--batch 8 chr
# 	--big-data
# 	--seed 1234
# 	--genes-only
# 	--bfile /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed
# 	--gene-annot /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot
# 	--pval /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.SNP.PVAL N=495
# 	--gene-model multi
# 	--out /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma
#
# Start time is 15:03:10, Saturday 06 Mar 2021
#
# Welcome to MAGMA v1.06 (linux)
# Using flags:
# 	--batch 1 chr
# 	--big-data
# 	--seed 1234
# 	--genes-only
# 	--bfile /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed
# 	--gene-annot /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot
# 	--pval /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.SNP.PVAL N=495
# 	--gene-model multi
# 	--out /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma
# Loading PLINK-format data...
# Reading file /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed.fam...
# Start time is 15:03:10, Saturday 06 Mar 2021
#
# Loading PLINK-format data...
# Reading file /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed.fam... 495 individuals read
# Reading file /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed.bim (chromosome 8 only)... Welcome to MAGMA v1.06 (linux)
# Using flags:
# 	--batch 4 chr
# 	--big-data
# 	--seed 1234
# 	--genes-only
# 	--bfile /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed
# 	--gene-annot /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot
# 	--pval /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.SNP.PVAL N=495
# 	--gene-model multi
# 	--out /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma
# 495 individuals read
#
# Start time is 15:03:10, Saturday 06 Mar 2021
#
# Reading file /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed.bim (chromosome 1 only)... Loading PLINK-format data...
# Reading file /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed.fam... 495 individuals read
# Reading file /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed.bim (chromosome 4 only)... Welcome to MAGMA v1.06 (linux)
# Using flags:
# 	--batch 5 chr
# 	--big-data
# 	--seed 1234
# 	--genes-only
# 	--bfile /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed
# 	--gene-annot /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot
# 	--pval /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.SNP.PVAL N=495
# 	--gene-model multi
# 	--out /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma
#
# Start time is 15:03:10, Saturday 06 Mar 2021
#
# Loading PLINK-format data...
# Reading file /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed.fam... 495 individuals read
# Reading file /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed.bim (chromosome 5 only)... Welcome to MAGMA v1.06 (linux)
# Using flags:
# 	--batch 9 chr
# 	--big-data
# 	--seed 1234
# 	--genes-only
# 	--bfile /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed
# 	--gene-annot /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot
# 	--pval /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.SNP.PVAL N=495
# 	--gene-model multi
# 	--out /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma
#
# Start time is 15:03:10, Saturday 06 Mar 2021
#
# Loading PLINK-format data...
# Reading file /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed.fam... 495 individuals read
# Reading file /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed.bim (chromosome 9 only)... Welcome to MAGMA v1.06 (linux)
# Using flags:
# 	--batch 2 chr
# 	--big-data
# 	--seed 1234
# 	--genes-only
# 	--bfile /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed
# 	--gene-annot /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot
# 	--pval /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.SNP.PVAL N=495
# 	--gene-model multi
# 	--out /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma
#
# Start time is 15:03:10, Saturday 06 Mar 2021
#
# Loading PLINK-format data...
# Reading file /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed.fam... 495 individuals read
# Reading file /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed.bim (chromosome 2 only)... Welcome to MAGMA v1.06 (linux)
# Using flags:
# 	--batch 10 chr
# 	--big-data
# 	--seed 1234
# 	--genes-only
# 	--bfile /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed
# 	--gene-annot /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot
# 	--pval /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.SNP.PVAL N=495
# 	--gene-model multi
# 	--out /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma
#
# Start time is 15:03:10, Saturday 06 Mar 2021
#
# Loading PLINK-format data...
# Reading file /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed.fam... 495 individuals read
# Reading file /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed.bim (chromosome 10 only)... Welcome to MAGMA v1.06 (linux)
# Using flags:
# 	--batch 11 chr
# 	--big-data
# 	--seed 1234
# 	--genes-only
# 	--bfile /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed
# 	--gene-annot /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot
# 	--pval /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.SNP.PVAL N=495
# 	--gene-model multi
# 	--out /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma
#
# Start time is 15:03:10, Saturday 06 Mar 2021
#
# Loading PLINK-format data...
# Reading file /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed.fam... 495 individuals read
# Reading file /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed.bim (chromosome 11 only)... Welcome to MAGMA v1.06 (linux)
# Using flags:
# 	--batch 3 chr
# 	--big-data
# 	--seed 1234
# 	--genes-only
# 	--bfile /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed
# 	--gene-annot /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot
# 	--pval /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.SNP.PVAL N=495
# 	--gene-model multi
# 	--out /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma
#
# Start time is 15:03:10, Saturday 06 Mar 2021
#
# Loading PLINK-format data...
# Reading file /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed.fam... 495 individuals read
# Reading file /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed.bim (chromosome 3 only)... Welcome to MAGMA v1.06 (linux)
# Using flags:
# 	--batch 12 chr
# 	--big-data
# 	--seed 1234
# 	--genes-only
# 	--bfile /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed
# 	--gene-annot /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot
# 	--pval /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.SNP.PVAL N=495
# 	--gene-model multi
# 	--out /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma
#
# Start time is 15:03:10, Saturday 06 Mar 2021
#
# Loading PLINK-format data...
# Reading file /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed.fam... 495 individuals read
# Reading file /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed.bim (chromosome 12 only)... Welcome to MAGMA v1.06 (linux)
# Using flags:
# 	--batch 13 chr
# 	--big-data
# 	--seed 1234
# 	--genes-only
# 	--bfile /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed
# 	--gene-annot /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot
# 	--pval /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.SNP.PVAL N=495
# 	--gene-model multi
# 	--out /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma
#
# Start time is 15:03:10, Saturday 06 Mar 2021
#
# Loading PLINK-format data...
# Reading file /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed.fam... 495 individuals read
# Reading file /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed.bim (chromosome 13 only)... Welcome to MAGMA v1.06 (linux)
# Using flags:
# 	--batch 14 chr
# 	--big-data
# 	--seed 1234
# 	--genes-only
# 	--bfile /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed
# 	--gene-annot /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot
# 	--pval /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.SNP.PVAL N=495
# 	--gene-model multi
# 	--out /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma
#
# Start time is 15:03:10, Saturday 06 Mar 2021
#
# Loading PLINK-format data...
# Reading file /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed.fam... 495 individuals read
# Reading file /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed.bim (chromosome 14 only)... Welcome to MAGMA v1.06 (linux)
# Using flags:
# 	--batch 15 chr
# 	--big-data
# 	--seed 1234
# 	--genes-only
# 	--bfile /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed
# 	--gene-annot /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot
# 	--pval /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.SNP.PVAL N=495
# 	--gene-model multi
# 	--out /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma
#
# Start time is 15:03:10, Saturday 06 Mar 2021
#
# Loading PLINK-format data...
# Reading file /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed.fam... 495 individuals read
# Reading file /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed.bim (chromosome 15 only)... Welcome to MAGMA v1.06 (linux)
# Using flags:
# 	--batch 16 chr
# 	--big-data
# 	--seed 1234
# 	--genes-only
# 	--bfile /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed
# 	--gene-annot /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot
# 	--pval /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.SNP.PVAL N=495
# 	--gene-model multi
# 	--out /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma
#
# Start time is 15:03:10, Saturday 06 Mar 2021
#
# Loading PLINK-format data...
# Reading file /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed.fam... 495 individuals read
# Reading file /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed.bim (chromosome 16 only)... Welcome to MAGMA v1.06 (linux)
# Using flags:
# 	--batch 17 chr
# 	--big-data
# 	--seed 1234
# 	--genes-only
# 	--bfile /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed
# 	--gene-annot /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot
# 	--pval /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.SNP.PVAL N=495
# 	--gene-model multi
# 	--out /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma
#
# Start time is 15:03:10, Saturday 06 Mar 2021
#
# Loading PLINK-format data...
# Reading file /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed.fam... 495 individuals read
# Reading file /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed.bim (chromosome 17 only)... Welcome to MAGMA v1.06 (linux)
# Using flags:
# 	--batch 18 chr
# 	--big-data
# 	--seed 1234
# 	--genes-only
# 	--bfile /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed
# 	--gene-annot /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot
# 	--pval /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.SNP.PVAL N=495
# 	--gene-model multi
# 	--out /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma
#
# Start time is 15:03:10, Saturday 06 Mar 2021
#
# Loading PLINK-format data...
# Reading file /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed.fam... 495 individuals read
# Reading file /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed.bim (chromosome 18 only)... Welcome to MAGMA v1.06 (linux)
# Using flags:
# 	--batch 19 chr
# 	--big-data
# 	--seed 1234
# 	--genes-only
# 	--bfile /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed
# 	--gene-annot /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot
# 	--pval /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.SNP.PVAL N=495
# 	--gene-model multi
# 	--out /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma
#
# Start time is 15:03:10, Saturday 06 Mar 2021
#
# Loading PLINK-format data...
# Reading file /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed.fam... 495 individuals read
# Reading file /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed.bim (chromosome 19 only)... Welcome to MAGMA v1.06 (linux)
# Using flags:
# 	--batch 21 chr
# 	--big-data
# 	--seed 1234
# 	--genes-only
# 	--bfile /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed
# 	--gene-annot /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot
# 	--pval /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.SNP.PVAL N=495
# 	--gene-model multi
# 	--out /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma
#
# Start time is 15:03:11, Saturday 06 Mar 2021
#
# Loading PLINK-format data...
# Reading file /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed.fam... 495 individuals read
# Reading file /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed.bim (chromosome 21 only)... Welcome to MAGMA v1.06 (linux)
# Using flags:
# 	--batch 22 chr
# 	--big-data
# 	--seed 1234
# 	--genes-only
# 	--bfile /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed
# 	--gene-annot /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot
# 	--pval /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.SNP.PVAL N=495
# 	--gene-model multi
# 	--out /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma
#
# Start time is 15:03:11, Saturday 06 Mar 2021
#
# Loading PLINK-format data...
# Reading file /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed.fam... 495 individuals read
# Reading file /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed.bim (chromosome 22 only)... Welcome to MAGMA v1.06 (linux)
# Using flags:
# 	--batch 7 chr
# 	--big-data
# 	--seed 1234
# 	--genes-only
# 	--bfile /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed
# 	--gene-annot /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot
# 	--pval /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.SNP.PVAL N=495
# 	--gene-model multi
# 	--out /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma
#
# Start time is 15:03:11, Saturday 06 Mar 2021
#
# Loading PLINK-format data...
# Reading file /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed.fam... 495 individuals read
# Reading file /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed.bim (chromosome 7 only)... Welcome to MAGMA v1.06 (linux)
# Using flags:
# 	--batch 20 chr
# 	--big-data
# 	--seed 1234
# 	--genes-only
# 	--bfile /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed
# 	--gene-annot /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot
# 	--pval /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.SNP.PVAL N=495
# 	--gene-model multi
# 	--out /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma
#
# Start time is 15:03:11, Saturday 06 Mar 2021
#
# Loading PLINK-format data...
# Reading file /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed.fam... 495 individuals read
# Reading file /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed.bim (chromosome 20 only)... Welcome to MAGMA v1.06 (linux)
# Using flags:
# 	--batch 6 chr
# 	--big-data
# 	--seed 1234
# 	--genes-only
# 	--bfile /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed
# 	--gene-annot /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot
# 	--pval /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.SNP.PVAL N=495
# 	--gene-model multi
# 	--out /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma
#
# Start time is 15:03:11, Saturday 06 Mar 2021
#
# Loading PLINK-format data...
# Reading file /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed.fam... 495 individuals read
# Reading file /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed.bim (chromosome 6 only)... 316140 SNPs read, of which 5188 used
# Preparing file /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed.bed...
#
# Reading SNP p-values from file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.SNP.PVAL...
# 	detected 2 variables in file
# 	using variable: SNP (SNP id)
# 	using variable: P (p-value)
# 316140 SNPs read, of which 9939 used
# Preparing file /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed.bed...
#
# Reading SNP p-values from file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.SNP.PVAL...
# 	detected 2 variables in file
# 	using variable: SNP (SNP id)
# 	using variable: P (p-value)
# 316140 SNPs read, of which 17957 used
# Preparing file /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed.bed...
#
# Reading SNP p-values from file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.SNP.PVAL...
# 	detected 2 variables in file
# 	using variable: SNP (SNP id)
# 	using variable: P (p-value)
# 316140 SNPs read, of which 20094 used
# Preparing file /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed.bed...
#
# Reading SNP p-values from file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.SNP.PVAL...
# 	detected 2 variables in file
# 	using variable: SNP (SNP id)
# 	using variable: P (p-value)
# 316140 SNPs read, of which 10322 used
# Preparing file /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed.bed...
#
# Reading SNP p-values from file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.SNP.PVAL...
# 	detected 2 variables in file
# 	using variable: SNP (SNP id)
# 	using variable: P (p-value)
# 316140 SNPs read, of which 24393 used
# Preparing file /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed.bed...
#
# Reading SNP p-values from file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.SNP.PVAL...
# 	detected 2 variables in file
# 	using variable: SNP (SNP id)
# 	using variable: P (p-value)
# 316140 SNPs read, of which 18647 used
# Preparing file /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed.bed...
#
# Reading SNP p-values from file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.SNP.PVAL...
# 	detected 2 variables in file
# 	using variable: SNP (SNP id)
# 	using variable: P (p-value)
# 316140 SNPs read, of which 8413 used
# Preparing file /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed.bed...
#
# Reading SNP p-values from file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.SNP.PVAL...
# 	detected 2 variables in file
# 	using variable: SNP (SNP id)
# 	using variable: P (p-value)
# 316140 SNPs read, of which 4451 used
# Preparing file /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed.bed...
#
# Reading SNP p-values from file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.SNP.PVAL...
# 	detected 2 variables in file
# 	using variable: SNP (SNP id)
# 	using variable: P (p-value)
# 316140 SNPs read, of which 7322 used
# Preparing file /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed.bed...
#
# Reading SNP p-values from file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.SNP.PVAL...
# 	detected 2 variables in file
# 	using variable: SNP (SNP id)
# 	using variable: P (p-value)
# 316140 SNPs read, of which 9060 used
# Preparing file /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed.bed...
#
# Reading SNP p-values from file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.SNP.PVAL...
# 	detected 2 variables in file
# 	using variable: SNP (SNP id)
# 	using variable: P (p-value)
# 316140 SNPs read, of which 13504 used
# Preparing file /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed.bed...
#
# Reading SNP p-values from file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.SNP.PVAL...
# 	detected 2 variables in file
# 	using variable: SNP (SNP id)
# 	using variable: P (p-value)
# 316140 SNPs read, of which 10829 used
# Preparing file /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed.bed...
#
# Reading SNP p-values from file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.SNP.PVAL...
# 	detected 2 variables in file
# 	using variable: SNP (SNP id)
# 	using variable: P (p-value)
# 316140 SNPs read, of which 24163 used
# Preparing file /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed.bed...
#
# Reading SNP p-values from file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.SNP.PVAL...
# 	detected 2 variables in file
# 	using variable: SNP (SNP id)
# 	using variable: P (p-value)
# 316140 SNPs read, of which 17152 used
# Preparing file /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed.bed...
#
# Reading SNP p-values from file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.SNP.PVAL...
# 	detected 2 variables in file
# 	using variable: SNP (SNP id)
# 	using variable: P (p-value)
# 316140 SNPs read, of which 9788 used
# Preparing file /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed.bed...
#
# Reading SNP p-values from file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.SNP.PVAL...
# 	detected 2 variables in file
# 	using variable: SNP (SNP id)
# 	using variable: P (p-value)
# 316140 SNPs read, of which 14904 used
# Preparing file /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed.bed...
#
# Reading SNP p-values from file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.SNP.PVAL...
# 	detected 2 variables in file
# 	using variable: SNP (SNP id)
# 	using variable: P (p-value)
# 316140 SNPs read, of which 10219 used
# Preparing file /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed.bed...
#
# Reading SNP p-values from file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.SNP.PVAL...
# 	detected 2 variables in file
# 	using variable: SNP (SNP id)
# 	using variable: P (p-value)
# 316140 SNPs read, of which 14571 used
# Preparing file /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed.bed...
#
# Reading SNP p-values from file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.SNP.PVAL...
# 	detected 2 variables in file
# 	using variable: SNP (SNP id)
# 	using variable: P (p-value)
# 316140 SNPs read, of which 20338 used
# Preparing file /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed.bed...
#
# Reading SNP p-values from file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.SNP.PVAL...
# 	detected 2 variables in file
# 	using variable: SNP (SNP id)
# 	using variable: P (p-value)
# 316140 SNPs read, of which 15458 used
# Preparing file /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed.bed...
#
# Reading SNP p-values from file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.SNP.PVAL...
# 	detected 2 variables in file
# 	using variable: SNP (SNP id)
# 	using variable: P (p-value)
# 316140 SNPs read, of which 15403 used
# Preparing file /mnt/data/GWAS/output/build38/task2.2_stratification/intermediate_datasets/dataset.b38.QCed.bed...
#
# Reading SNP p-values from file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.SNP.PVAL...
# 	detected 2 variables in file
# 	using variable: SNP (SNP id)
# 	using variable: P (p-value)
# 	read 8976887 lines from file, containing valid SNP p-values for 4225 SNPs in data (0.04707% of lines, 42.51% of SNPs in data)
# Filtering phenotype/covariate missing values... 495 individuals remaining
#
# Loading gene annotation from file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot...
# 	read 8976887 lines from file, containing valid SNP p-values for 9565 SNPs in data (0.1066% of lines, 47.6% of SNPs in data)
# Filtering phenotype/covariate missing values... 495 individuals remaining
#
# Loading gene annotation from file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot...
# 	read 8976887 lines from file, containing valid SNP p-values for 2294 SNPs in data (0.02555% of lines, 44.22% of SNPs in data)
# Filtering phenotype/covariate missing values... 495 individuals remaining
#
# Loading gene annotation from file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot...
# 	read 8976887 lines from file, containing valid SNP p-values for 4431 SNPs in data (0.04936% of lines, 48.91% of SNPs in data)
# Filtering phenotype/covariate missing values... 495 individuals remaining
#
# Loading gene annotation from file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot...
# 	1197 gene definitions read from file
# 	found 1162 genes containing SNPs in genotype data
#
# Starting gene analysis...
# 	using multi-model containing:
# 		SNPwise-mean
# 		SNPwise-top
# 	analysing chromosome 17, containing 1162 genes
# 	WARNING: disabling 'big-data' mode, sample size is too small
# 	459 gene definitions read from file
# 	found 439 genes containing SNPs in genotype data
#
# Starting gene analysis...
# 	using multi-model containing:
# 		SNPwise-mean
# 		SNPwise-top
# 	analysing chromosome 22, containing 439 genes
# 	WARNING: disabling 'big-data' mode, sample size is too small
# 	763 gene definitions read from file
# 	found 744 genes containing SNPs in genotype data
#
# Starting gene analysis...
# 	using multi-model containing:
# 		SNPwise-mean
# 		SNPwise-top
# 	analysing chromosome 4, containing 744 genes
# 	WARNING: disabling 'big-data' mode, sample size is too small
# 	283 gene definitions read from file
# 	found 283 genes containing SNPs in genotype data
#
# Starting gene analysis...
# 	using multi-model containing:
# 		SNPwise-mean
# 		SNPwise-top
# 	analysing chromosome 18, containing 283 genes
# 	WARNING: disabling 'big-data' mode, sample size is too small
# 	read 8976887 lines from file, containing valid SNP p-values for 2090 SNPs in data (0.02328% of lines, 46.96% of SNPs in data)
# Filtering phenotype/covariate missing values... 495 individuals remaining
#
# Loading gene annotation from file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot...
# 	read 8976887 lines from file, containing valid SNP p-values for 3726 SNPs in data (0.04151% of lines, 50.89% of SNPs in data)
# Filtering phenotype/covariate missing values... 495 individuals remaining
#
# Loading gene annotation from file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot...
# 	read 8976887 lines from file, containing valid SNP p-values for 3422 SNPs in data (0.03812% of lines, 40.68% of SNPs in data)
# Filtering phenotype/covariate missing values... 495 individuals remaining
#
# Loading gene annotation from file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot...
# 	read 8976887 lines from file, containing valid SNP p-values for 4735 SNPs in data (0.05275% of lines, 46.34% of SNPs in data)
# Filtering phenotype/covariate missing values... 495 individuals remaining
#
# Loading gene annotation from file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot...
# 	224 gene definitions read from file
# 	found 211 genes containing SNPs in genotype data
#
# Starting gene analysis...
# 	using multi-model containing:
# 		SNPwise-mean
# 		SNPwise-top
# 	analysing chromosome 21, containing 211 genes
# 	WARNING: disabling 'big-data' mode, sample size is too small
# 	read 8976887 lines from file, containing valid SNP p-values for 6812 SNPs in data (0.07588% of lines, 46.75% of SNPs in data)
# Filtering phenotype/covariate missing values... 495 individuals remaining
#
# Loading gene annotation from file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot...
# 	read 8976887 lines from file, containing valid SNP p-values for 5276 SNPs in data (0.05877% of lines, 48.72% of SNPs in data)
# Filtering phenotype/covariate missing values... 495 individuals remaining
#
# Loading gene annotation from file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot...
# 	read 8976887 lines from file, containing valid SNP p-values for 4478 SNPs in data (0.04988% of lines, 43.38% of SNPs in data)
# Filtering phenotype/covariate missing values... 495 individuals remaining
#
# Loading gene annotation from file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot...
# 	537 gene definitions read from file
# 	found 531 genes containing SNPs in genotype data
#
# Starting gene analysis...
# 	using multi-model containing:
# 		SNPwise-mean
# 		SNPwise-top
# 	analysing chromosome 20, containing 531 genes
# 	WARNING: disabling 'big-data' mode, sample size is too small
# 	read 8976887 lines from file, containing valid SNP p-values for 11365 SNPs in data (0.1266% of lines, 47.03% of SNPs in data)
# Filtering phenotype/covariate missing values... 495 individuals remaining
#
# Loading gene annotation from file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot...
# 	read 8976887 lines from file, containing valid SNP p-values for 7886 SNPs in data (0.08785% of lines, 45.98% of SNPs in data)
# Filtering phenotype/covariate missing values... 495 individuals remaining
#
# Loading gene annotation from file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot...
# 	read 8976887 lines from file, containing valid SNP p-values for 11105 SNPs in data (0.1237% of lines, 45.53% of SNPs in data)
# Filtering phenotype/covariate missing values... 495 individuals remaining
#
# Loading gene annotation from file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot...
# 	1423 gene definitions read from file
# 	found 1416 genes containing SNPs in genotype data
#
# Starting gene analysis...
# 	using multi-model containing:
# 		SNPwise-mean
# 		SNPwise-top
# 	analysing chromosome 19, containing 1416 genes
# 	WARNING: disabling 'big-data' mode, sample size is too small
# 	read 8976887 lines from file, containing valid SNP p-values for 8857 SNPs in data (0.09866% of lines, 47.5% of SNPs in data)
# Filtering phenotype/covariate missing values... 495 individuals remaining
#
# Loading gene annotation from file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot...
# 	606 gene definitions read from file
# 	found 600 genes containing SNPs in genotype data
#
# Starting gene analysis...
# 	using multi-model containing:
# 		SNPwise-mean
# 		SNPwise-top
# 	analysing chromosome 14, containing 600 genes
# 	WARNING: disabling 'big-data' mode, sample size is too small
# 	341 gene definitions read from file
# 	found 335 genes containing SNPs in genotype data
#
# Starting gene analysis...
# 	using multi-model containing:
# 		SNPwise-mean
# 		SNPwise-top
# 	analysing chromosome 13, containing 335 genes
# 	WARNING: disabling 'big-data' mode, sample size is too small
# 	read 8976887 lines from file, containing valid SNP p-values for 7204 SNPs in data (0.08025% of lines, 46.77% of SNPs in data)
# Filtering phenotype/covariate missing values... 495 individuals remaining
#
# Loading gene annotation from file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot...
# 	read 8976887 lines from file, containing valid SNP p-values for 7396 SNPs in data (0.08239% of lines, 47.85% of SNPs in data)
# Filtering phenotype/covariate missing values... 495 individuals remaining
#
# Loading gene annotation from file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot...
# 	1299 gene definitions read from file
# 	found 1244 genes containing SNPs in genotype data
#
# Starting gene analysis...
# 	using multi-model containing:
# 		SNPwise-mean
# 		SNPwise-top
# 	analysing chromosome 11, containing 1244 genes
# 	WARNING: disabling 'big-data' mode, sample size is too small
# 	860 gene definitions read from file
# 	found 806 genes containing SNPs in genotype data
#
# Starting gene analysis...
# 	using multi-model containing:
# 		SNPwise-mean
# 		SNPwise-top
# 	analysing chromosome 16, containing 806 genes
# 	WARNING: disabling 'big-data' mode, sample size is too small
# 	read 8976887 lines from file, containing valid SNP p-values for 4266 SNPs in data (0.04752% of lines, 43.58% of SNPs in data)
# Filtering phenotype/covariate missing values... 495 individuals remaining
#
# Loading gene annotation from file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot...
# 	read 8976887 lines from file, containing valid SNP p-values for 6245 SNPs in data (0.06957% of lines, 46.25% of SNPs in data)
# Filtering phenotype/covariate missing values... 495 individuals remaining
#
# Loading gene annotation from file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot...
# 	942 gene definitions read from file
# 	found 909 genes containing SNPs in genotype data
#
# Starting gene analysis...
# 	using multi-model containing:
# 		SNPwise-mean
# 		SNPwise-top
# 	analysing chromosome 7, containing 909 genes
# 	WARNING: disabling 'big-data' mode, sample size is too small
# 	1284 gene definitions read from file
# 	found 1235 genes containing SNPs in genotype data
#
# Starting gene analysis...
# 	using multi-model containing:
# 		SNPwise-mean
# 		SNPwise-top
# 	analysing chromosome 2, containing 1235 genes
# 	WARNING: disabling 'big-data' mode, sample size is too small
# 	748 gene definitions read from file
# 	found 727 genes containing SNPs in genotype data
#
# Starting gene analysis...
# 	using multi-model containing:
# 		SNPwise-mean
# 		SNPwise-top
# 	analysing chromosome 10, containing 727 genes
# 	WARNING: disabling 'big-data' mode, sample size is too small
# 	read 8976887 lines from file, containing valid SNP p-values for 6715 SNPs in data (0.0748% of lines, 45.06% of SNPs in data)
# Filtering phenotype/covariate missing values... 495 individuals remaining
#
# Loading gene annotation from file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot...
# 	679 gene definitions read from file
# 	found 652 genes containing SNPs in genotype data
#
# Starting gene analysis...
# 	using multi-model containing:
# 		SNPwise-mean
# 		SNPwise-top
# 	analysing chromosome 8, containing 652 genes
# 	WARNING: disabling 'big-data' mode, sample size is too small
# 	1053 gene definitions read from file
# 	found 1042 genes containing SNPs in genotype data
#
# Starting gene analysis...
# 	using multi-model containing:
# 		SNPwise-mean
# 		SNPwise-top
# 	analysing chromosome 6, containing 1042 genes
# 	WARNING: disabling 'big-data' mode, sample size is too small
# 	2087 gene definitions read from file
# 	found 1974 genes containing SNPs in genotype data
#
# Starting gene analysis...
# 	using multi-model containing:
# 		SNPwise-mean
# 		SNPwise-top
# 	analysing chromosome 1, containing 1974 genes
# 	WARNING: disabling 'big-data' mode, sample size is too small
# 	603 gene definitions read from file
# 	found 575 genes containing SNPs in genotype data
#
# Starting gene analysis...
# 	using multi-model containing:
# 		SNPwise-mean
# 		SNPwise-top
# 	analysing chromosome 15, containing 575 genes
# 	WARNING: disabling 'big-data' mode, sample size is too small
# 	read 8976887 lines from file, containing valid SNP p-values for 9876 SNPs in data (0.11% of lines, 48.56% of SNPs in data)
# Filtering phenotype/covariate missing values... 495 individuals remaining
#
# Loading gene annotation from file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot...
# 	777 gene definitions read from file
# 	found 762 genes containing SNPs in genotype data
#
# Starting gene analysis...
# 	using multi-model containing:
# 		SNPwise-mean
# 		SNPwise-top
# 	analysing chromosome 9, containing 762 genes
# 	WARNING: disabling 'big-data' mode, sample size is too small
# 	1032 gene definitions read from file
# 	found 1015 genes containing SNPs in genotype data
#
# Starting gene analysis...
# 	using multi-model containing:
# 		SNPwise-mean
# 		SNPwise-top
# 	analysing chromosome 12, containing 1015 genes
# 	WARNING: disabling 'big-data' mode, sample size is too small
# 	1078 gene definitions read from file
# 	found 1061 genes containing SNPs in genotype data
#
# Starting gene analysis...
# 	using multi-model containing:
# 		SNPwise-mean
# 		SNPwise-top
# 	analysing chromosome 3, containing 1061 genes
# 	WARNING: disabling 'big-data' mode, sample size is too small
# 	read 8976887 lines from file, containing valid SNP p-values for 8678 SNPs in data (0.09667% of lines, 48.33% of SNPs in data)
# Filtering phenotype/covariate missing values... 495 individuals remaining
#
# Loading gene annotation from file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot...
# 	883 gene definitions read from file
# 	found 862 genes containing SNPs in genotype data
#
# Starting gene analysis...
# 	using multi-model containing:
# 		SNPwise-mean
# 		SNPwise-top
# 	analysing chromosome 5, containing 862 genes
# 	WARNING: disabling 'big-data' mode, sample size is too small
# 	writing gene analysis results to file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch21_chr.genes.out
#
#
# End time is 15:03:36, Saturday 06 Mar 2021 (elapsed: 00:00:25)
# 	writing gene analysis results to file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch18_chr.genes.out
# 	processed genes: 271 (80.9%)
#
# End time is 15:03:45, Saturday 06 Mar 2021 (elapsed: 00:00:35)
# 	writing gene analysis results to file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch22_chr.genes.out
#
#
# End time is 15:03:48, Saturday 06 Mar 2021 (elapsed: 00:00:37)
# 	writing gene analysis results to file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch13_chr.genes.out
#
#
# End time is 15:03:50, Saturday 06 Mar 2021 (elapsed: 00:00:40)
# 	writing gene analysis results to file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch20_chr.genes.out
#
#
# End time is 15:03:55, Saturday 06 Mar 2021 (elapsed: 00:00:44)
# 	writing gene analysis results to file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch15_chr.genes.out
#
#
# End time is 15:03:55, Saturday 06 Mar 2021 (elapsed: 00:00:45)
# 	writing gene analysis results to file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch14_chr.genes.out
#
#
# End time is 15:03:58, Saturday 06 Mar 2021 (elapsed: 00:00:48)
# 	writing gene analysis results to file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch16_chr.genes.out
#
#
# End time is 15:04:01, Saturday 06 Mar 2021 (elapsed: 00:00:51)
# 	writing gene analysis results to file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch8_chr.genes.out
#
#
# End time is 15:04:03, Saturday 06 Mar 2021 (elapsed: 00:00:53)
# 	writing gene analysis results to file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch17_chr.genes.out
#
#
# End time is 15:04:03, Saturday 06 Mar 2021 (elapsed: 00:00:53)
# 	writing gene analysis results to file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch9_chr.genes.out
#
#
# End time is 15:04:04, Saturday 06 Mar 2021 (elapsed: 00:00:54)
# 	writing gene analysis results to file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch4_chr.genes.out
#
#
# End time is 15:04:04, Saturday 06 Mar 2021 (elapsed: 00:00:54)
# 	writing gene analysis results to file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch10_chr.genes.out
#
#
# End time is 15:04:05, Saturday 06 Mar 2021 (elapsed: 00:00:55)
# 	writing gene analysis results to file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch7_chr.genes.out
#
#
# End time is 15:04:06, Saturday 06 Mar 2021 (elapsed: 00:00:55)
# 	writing gene analysis results to file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch5_chr.genes.out
#
#
# End time is 15:04:06, Saturday 06 Mar 2021 (elapsed: 00:00:56)
# 	writing gene analysis results to file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch12_chr.genes.out
#
#
# End time is 15:04:07, Saturday 06 Mar 2021 (elapsed: 00:00:57)
# 	writing gene analysis results to file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch11_chr.genes.out
#
#
# End time is 15:04:08, Saturday 06 Mar 2021 (elapsed: 00:00:58)
# 	writing gene analysis results to file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch6_chr.genes.out
#
#
# End time is 15:04:10, Saturday 06 Mar 2021 (elapsed: 00:00:59)
# 	writing gene analysis results to file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch19_chr.genes.out
#
#
# End time is 15:04:10, Saturday 06 Mar 2021 (elapsed: 00:01:00)
# 	writing gene analysis results to file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch2_chr.genes.out
#
#
# End time is 15:04:10, Saturday 06 Mar 2021 (elapsed: 00:01:00)
# 	writing gene analysis results to file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch3_chr.genes.out
#
#
# End time is 15:04:12, Saturday 06 Mar 2021 (elapsed: 00:01:02)
# 	writing gene analysis results to file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch1_chr.genes.out
#
#
# End time is 15:04:15, Saturday 06 Mar 2021 (elapsed: 00:01:05)

# %%
# %%bash
# #merge batches
# #/usr/lib/magma/magma
# magma --merge $path/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma --out $path/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma
# head $path/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.genes.out
# Out:
# Welcome to MAGMA v1.06 (linux)
# Using flags:
# 	--merge /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma
# 	--out /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma
#
# Start time is 15:04:15, Saturday 06 Mar 2021
#
# Merging gene results files with prefix '/mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma'...
# 	WARNING: found only 0 .genes.raw batch files for chromosomes 1-22
# Reading file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch1_chr.genes.out...
# 	1974 genes read from file
# Reading file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch2_chr.genes.out...
# 	1235 genes read from file
# Reading file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch3_chr.genes.out...
# 	1061 genes read from file
# Reading file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch4_chr.genes.out...
# 	744 genes read from file
# Reading file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch5_chr.genes.out...
# 	862 genes read from file
# Reading file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch6_chr.genes.out...
# 	1042 genes read from file
# Reading file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch7_chr.genes.out...
# 	909 genes read from file
# Reading file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch8_chr.genes.out...
# 	652 genes read from file
# Reading file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch9_chr.genes.out...
# 	762 genes read from file
# Reading file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch10_chr.genes.out...
# 	727 genes read from file
# Reading file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch11_chr.genes.out...
# 	1244 genes read from file
# Reading file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch12_chr.genes.out...
# 	1015 genes read from file
# Reading file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch13_chr.genes.out...
# 	335 genes read from file
# Reading file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch14_chr.genes.out...
# 	600 genes read from file
# Reading file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch15_chr.genes.out...
# 	575 genes read from file
# Reading file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch16_chr.genes.out...
# 	806 genes read from file
# Reading file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch17_chr.genes.out...
# 	1162 genes read from file
# Reading file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch18_chr.genes.out...
# 	283 genes read from file
# Reading file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch19_chr.genes.out...
# 	1416 genes read from file
# Reading file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch20_chr.genes.out...
# 	531 genes read from file
# Reading file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch21_chr.genes.out...
# 	211 genes read from file
# Reading file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.batch22_chr.genes.out...
# 	439 genes read from file
# Writing merged gene analysis results to file /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.genes.out
#
#
# End time is 15:04:15, Saturday 06 Mar 2021 (elapsed: 00:00:00)
# GENE       CHR      START       STOP  NSNPS  NPARAM    N        ZSTAT      P_JOINT  P_SNPWISE_MEAN  P_SNPWISE_TOP1
# 105378580    1     753398     855130      5       4  495       2.3677    0.0089488       0.0097317        0.014253
# 148398       1     875741     994581     10       9  495       1.0111      0.15597         0.10946         0.23968
# 26155        1     894203    1009299      9       8  495      0.90113      0.18376         0.16222         0.21856
# 339451       1     909952    1015720      7       6  495      0.76407      0.22241         0.28831         0.17454
# 84069        1     916497    1025108      9       8  495      0.51199      0.30433         0.41519         0.21856
# 84808        1     925199    1032117      9       8  495      0.51199      0.30433         0.41519         0.21856
# 57801        1     948962    1051285      9       8  495      0.82705       0.2041         0.19898         0.21856
# 9636         1     963467    1064540     10       9  495      0.64915      0.25812          0.2787         0.23968
# 375790       1     970101    1106119     15      12  495      -0.8976       0.8153         0.75429         0.77866

# %%
# %%bash
# sort -gk10,10 $path/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.genes.out >$path/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.genes.out.sorted
# head $path/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.genes.out.sorted
# Out:
# GENE       CHR      START       STOP  NSNPS  NPARAM    N        ZSTAT      P_JOINT  P_SNPWISE_MEAN  P_SNPWISE_TOP1
# 11214       15   85330616   85799358     20      13  495        3.813   6.8633e-05      1.8683e-05       0.0013226
# 134111       5    6387347    6546721     17      14  495       3.7768   7.9438e-05      5.6238e-05       0.0018005
# 26074       20   20002514   20410714     25      19  495       3.6031   0.00015722      7.9538e-05       0.0047978
# 57117        4  105632627  105758729      5       4  495       2.9638    0.0015192       0.0001333        0.037451
# 2197        11   65070627   65172200      1       1  495       3.5637    0.0001828       0.0001828       0.0001828
# 741         11   65066403   65167738      1       1  495       3.5637    0.0001828       0.0001828       0.0001828
# 30811       21   31823315   32054064     18      15  495       2.9599    0.0015389       0.0002843        0.049541
# 132884       4    5484397    5759548     26      21  495        3.242   0.00059339      0.00031645       0.0069702
# 51250        6  106978172  107101586      8       7  495       3.0124    0.0012961      0.00042762        0.012777

# %%
# %%R
# # Add HUGO gene name using the refernece file NCBI38.gene.loc linking oficial gene symbols  and GenBank Ids
# magma<-read.table("/mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.genes.out.sorted", header=TRUE)
# genes<-read.table("/mnt/data/GWAS/ref_files/build38/NCBI38.gene.loc")
# genes<-genes[-c(2:4)]
# head(genes)
# colnames(genes) <- c("GENE","STRAND","HUGO")
#
# magma_merged<-merge(magma,genes, by="GENE")
# magma_merged <- magma_merged[order(magma_merged$P_SNPWISE_MEAN), ]
# magma_rank<-rank(magma_merged[,10],na.last = "keep", ties.method = "min")
# magma_ranked=cbind(magma_rank, magma_merged)
#
# write.table(magma_ranked, "/mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.genes.out.sorted.annot", quote=FALSE, sep="\t", row.names = FALSE)

# %%
# %%bash
# head /mnt/data/GWAS/output/build38/task6_genewise/dataset.b38.imputed.dosage.maf.0.01.LOC.50kb.genes.annot.magma.genes.out.sorted.annot
# Out:
# magma_rank	GENE	CHR	START	STOP	NSNPS	NPARAM	N	ZSTAT	P_JOINT	P_SNPWISE_MEAN	P_SNPWISE_TOP1	STRAND	HUGO
# 1	11214	15	85330616	85799358	20	13	495	3.813	6.8633e-05	1.8683e-05	0.0013226	+	AKAP13
# 2	134111	5	6387347	6546721	17	14	495	3.7768	7.9438e-05	5.6238e-05	0.0018005	+	UBE2QL1
# 3	26074	20	20002514	20410714	25	19	495	3.6031	0.00015722	7.9538e-05	0.0047978	+	CFAP61
# 4	57117	4	105632627	105758729	5	4	495	2.9638	0.0015192	0.0001333	0.037451	-	INTS12
# 5	741	11	65066403	65167738	1	1	495	3.5637	0.0001828	0.0001828	0.0001828	-	ZNHIT2
# 5	2197	11	65070627	65172200	1	1	495	3.5637	0.0001828	0.0001828	0.0001828	-	FAU
# 7	30811	21	31823315	32054064	18	15	495	2.9599	0.0015389	0.0002843	0.049541	+	HUNK
# 8	132884	4	5484397	5759548	26	21	495	3.242	0.00059339	0.00031645	0.0069702	-	EVC2
# 9	51250	6	106978172	107101586	8	7	495	3.0124	0.0012961	0.00042762	0.012777	+	C6orf203
