# %% [markdown]
# # Manhattans and QQplots
#
# GWAS results are often displayed in a Manhattan plot with -log10(p-value) plotted against the position in the genome.
#
# A p-value indicates the significance of the difference in frequency of the allele tested between cases and controls i.e. the probability that the allele is likely to be associated with the trait.

# %%
suppressPackageStartupMessages(library(qqman))

# %%
path<-"/mnt/data/GWAS/output/build38/task4_assoc/"
results_assoc <- read.table(paste0(path,"dataset.b38.imputed.assoc.dosage.clean.rs.200kb.annot"), head=TRUE)
dim(results_assoc)
head(results_assoc)
# Out:
# [1] 8976886      12
#   CHR BP        SNP               A1 A2 FRQ    INFO   OR     SE     P
# 1 10  100000235 10:100000235:C:T  C  T  0.2982 0.7959 0.6679 0.3084 0.1906
# 2 10  100000943 10:100000943:G:A  G  A  0.0929 0.7945 1.2681 0.5058 0.6387
# 3 10  100000979 10:100000979:T:C  T  C  0.0504 0.7881 1.7337 0.7499 0.4631
# 4 10  100002012 10:100002012:T:C  T  C  0.0374 0.8215 1.0097 0.6786 0.9886
# 5 10  100002038 10:100002038:G:A  G  A  0.0102 0.8861 3.0510 1.3529 0.4097
# 6 10  100002300 10:100002300:GA:G GA G  0.0374 0.8216 1.0082 0.6788 0.9904
#   RS
# 1 rs11596870
# 2 rs11190359
# 3 rs11190360
# 4 rs11190362
# 5 rs192480913
# 6 rs111354488
#   ANNOT
# 1 ABCC2(+148kb)|CHUK(-188.1kb)|CPN1(-42.07kb)|DNMBP(0)|DNMBP-AS1(+41.24kb)|ERLIN1(-149.9kb)
# 2 ABCC2(+148.8kb)|CHUK(-187.4kb)|CPN1(-41.36kb)|DNMBP(0)|DNMBP-AS1(+41.94kb)|ERLIN1(-149.1kb)
# 3 ABCC2(+148.8kb)|CHUK(-187.4kb)|CPN1(-41.33kb)|DNMBP(0)|DNMBP-AS1(+41.98kb)|ERLIN1(-149.1kb)
# 4 ABCC2(+149.8kb)|CHUK(-186.4kb)|CPN1(-40.3kb)|DNMBP(0)|DNMBP-AS1(+43.01kb)|ERLIN1(-148.1kb)
# 5 ABCC2(+149.8kb)|CHUK(-186.3kb)|CPN1(-40.27kb)|DNMBP(0)|DNMBP-AS1(+43.04kb)|ERLIN1(-148.1kb)
# 6 ABCC2(+150.1kb)|CHUK(-186.1kb)|CPN1(-40.01kb)|DNMBP(0)|DNMBP-AS1(+43.3kb)|ERLIN1(-147.8kb)

# %% [markdown]
# ## Manhattans

# %%
# jpeg("path/Manhattan.jpeg")
manhattan(results_assoc, chr = "CHR", bp = "BP", p = "P", snp = "SNP", col = c("coral", "aquamarine4"), chrlabs = NULL, suggestiveline = -log10(1e-04), genomewideline = -log10(5e-08), highlight = NULL, logp = TRUE, main = "Manhattan plot", ylim = c(0, 10), cex = 0.6, cex.axis = 0.9)
#dev.off()
# Out:
# Plot with title "Manhattan plot"

# %% [markdown]
# ## QQ plots

# %%
qq(results_assoc$P, main = "Q-Q plot of GWAS p-values")
# Out:
# Plot with title "Q-Q plot of GWAS p-values"
