# %% [markdown]
# # Task 3: Imputation
#
# After the QC, genotype imputation can be performed with the minimac 3 algorithm at the University of Michigan server using the HRC reference panel, and the SHAPEIT tool for haplotype phasing. After imputation, SNPs with an R2 quality estimate lower than 0.3 are excluded from further analyses according to the software recommendations.
#
# To run this notebook you need the bfile dataset.b3.QCed, generated on previous task Population stratification.
#
# https://rstudio-pubs-static.s3.amazonaws.com/452627_d519d1c86bd249e6a2d9638ef1ea836c.html

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Preparing-the-dataset-for-imputation" data-toc-modified-id="Preparing-the-dataset-for-imputation-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Preparing the dataset for imputation</a></span></li><li><span><a href="#Upload-vcf.gz-files-to-the-Michigan-server-(phasing:-SHAPE-IT;-reference:HRC;-mode:-QC&amp;imputation)" data-toc-modified-id="Upload-vcf.gz-files-to-the-Michigan-server-(phasing:-SHAPE-IT;-reference:HRC;-mode:-QC&amp;imputation)-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Upload vcf.gz files to the Michigan server (phasing: SHAPE-IT; reference:HRC; mode: QC&amp;imputation)</a></span></li><li><span><a href="#QC-of-the-imputed-genotypes" data-toc-modified-id="QC-of-the-imputed-genotypes-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>QC of the imputed genotypes</a></span></li></ul></div>

# %%
# %load_ext rpy2.ipython
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython

# %%
# %env path=/mnt/data/GWAS/output/task3_imputation
# Out:
# env: path=/mnt/data/GWAS/output/task3_imputation

# %% [markdown]
# ##  Preparing the dataset for imputation
#
# We will use Will Rayner's toolbox to prepare the data. (https://www.well.ox.ac.uk/~wrayner/tools/)

# %%
# %%bash
# # Determine allele frequencies in the dataset
# plink --bfile /mnt/data/GWAS/output/task2.2_stratification/intermediate_datasets/dataset.b37.outliers  --freq --out $path/dataset.b37.outliers.freq
# Out:
# PLINK v1.90b3.45 64-bit (13 Jan 2017)      https://www.cog-genomics.org/plink2
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /mnt/data/GWAS/output/task3_imputation/dataset.b37.outliers.freq.log.
# Options in effect:
#   --bfile /mnt/data/GWAS/output/task2.2_stratification/intermediate_datasets/dataset.b37.outliers
#   --freq
#   --out /mnt/data/GWAS/output/task3_imputation/dataset.b37.outliers.freq
#
# 32127 MB RAM detected; reserving 16063 MB for main workspace.
# 7076087 variants loaded from .bim file.
# 496 people (237 males, 259 females) loaded from .fam.
# 496 phenotype values loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 496 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.999931.
# --freq: Allele frequencies (founders only) written to
# /mnt/data/GWAS/output/task3_imputation/dataset.b37.outliers.freq.frq .
# Warning: 1060176 het. haploid genotypes present (see
# /mnt/data/GWAS/output/task3_imputation/dataset.b37.outliers.freq.hh ); many
# commands treat these as missing.

# %% [markdown]
# **Run the perl script from Will Rayner's toolbox to check plink .bim files against HRC/1000G for strand, id names, positions, alleles, ref/alt assignment.**
#
# A specific population to check frequency against can be changed with -p (Default ALL, options ALL, EUR, AFR, AMR, SAS, EAS)
#
# Using the terminal (New->Terminal from Jupyter panel or from the terminal inside your docker container) create a bash script containing the perl command. Provide execution permission (chmod +x) and run it (./HRC.sh). Place the script where the path environment variable points.
#
# Next, run from terminal the Run-plink.sh created by the perl one.
#
# **IMPORTANT: Do not run this script on momic.us.es.** This script needs 30Gb of RAM to run. The ouput of this command is stored in the path where the environment variable 'path' points to. If the user needs to impute his own data, install this pipeline locally following the User Manual.

# %% [raw]
# #!bin/bash
# perl /mnt/data/GWAS/scripts/HRC-1000G-check-bim.pl -v -b dataset.b37.outliers.bim  -f dataset.b37.outliers.freq.frq -r /mnt/data/GWAS/ref_files/HRC.r1-1.GRCh37.wgs.mac5.sites.tab -h > dataset.b37.HRC-check.log

# %% [raw]
# bash Run-plink.sh > Run-plink.log

# %%
# %%bash
# cat $path/run-plink.log
# Out:
# PLINK v1.90b6.17 64-bit (28 Apr 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to TEMP1.log.
# Options in effect:
#   --bfile dataset.b37.outliers
#   --exclude Exclude-dataset.b37.outliers-HRC.txt
#   --make-bed
#   --out TEMP1
#
# 257718 MB RAM detected; reserving 128859 MB for main workspace.
# 7076087 variants loaded from .bim file.
# 496 people (237 males, 259 females) loaded from .fam.
# 496 phenotype values loaded from .fam.
# --exclude: 5436495 variants remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 496 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.999985.
# 5436495 variants and 496 people pass filters and QC.
# Among remaining phenotypes, 203 are cases and 293 are controls.
# --make-bed to TEMP1.bed + TEMP1.bim + TEMP1.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b6.17 64-bit (28 Apr 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to TEMP2.log.
# Options in effect:
#   --bfile TEMP1
#   --make-bed
#   --out TEMP2
#   --update-chr
#   --update-map Chromosome-dataset.b37.outliers-HRC.txt
#
# Note: --update-map <filename> + parameter-free --update-chr deprecated.  Use
# --update-chr <filename> instead.
# 257718 MB RAM detected; reserving 128859 MB for main workspace.
# 5436495 variants loaded from .bim file.
# 496 people (237 males, 259 females) loaded from .fam.
# 496 phenotype values loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 496 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.999985.
# 5436495 variants and 496 people pass filters and QC.
# Among remaining phenotypes, 203 are cases and 293 are controls.
# --update-chr: 2 values updated, 13 variant IDs not present.
# --make-bed to TEMP2.bed + TEMP2.bim + TEMP2.fam ... .
# PLINK v1.90b6.17 64-bit (28 Apr 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to TEMP3.log.
# Options in effect:
#   --bfile TEMP2
#   --make-bed
#   --out TEMP3
#   --update-map Position-dataset.b37.outliers-HRC.txt
#
# 257718 MB RAM detected; reserving 128859 MB for main workspace.
# 5436495 variants loaded from .bim file.
# 496 people (237 males, 259 females) loaded from .fam.
# 496 phenotype values loaded from .fam.
# --update-map: 2 values updated, 13 variant IDs not present.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 496 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.999985.
# 5436495 variants and 496 people pass filters and QC.
# Among remaining phenotypes, 203 are cases and 293 are controls.
# --make-bed to TEMP3.bed + TEMP3.bim + TEMP3.fam ... .
# PLINK v1.90b6.17 64-bit (28 Apr 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to TEMP4.log.
# Options in effect:
#   --bfile TEMP3
#   --flip Strand-Flip-dataset.b37.outliers-HRC.txt
#   --make-bed
#   --out TEMP4
#
# 257718 MB RAM detected; reserving 128859 MB for main workspace.
# 5436495 variants loaded from .bim file.
# 496 people (237 males, 259 females) loaded from .fam.
# 496 phenotype values loaded from .fam.
# --flip: 1 SNP flipped.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 496 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.999985.
# 5436495 variants and 496 people pass filters and QC.
# Among remaining phenotypes, 203 are cases and 293 are controls.
# --make-bed to TEMP4.bed + TEMP4.bim + TEMP4.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b6.17 64-bit (28 Apr 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to dataset.b37.outliers-updated.log.
# Options in effect:
#   --a1-allele Force-Allele1-dataset.b37.outliers-HRC.txt
#   --bfile TEMP4
#   --make-bed
#   --out dataset.b37.outliers-updated
#
# 257718 MB RAM detected; reserving 128859 MB for main workspace.
# 5436495 variants loaded from .bim file.
# 496 people (237 males, 259 females) loaded from .fam.
# 496 phenotype values loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 496 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.999985.
# --a1-allele: 5436495 assignments made.
# 5436495 variants and 496 people pass filters and QC.
# Among remaining phenotypes, 203 are cases and 293 are controls.
# --make-bed to dataset.b37.outliers-updated.bed +
# dataset.b37.outliers-updated.bim + dataset.b37.outliers-updated.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b6.17 64-bit (28 Apr 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to dataset.b37.outliers-updated-chr1.log.
# Options in effect:
#   --a1-allele Force-Allele1-dataset.b37.outliers-HRC.txt
#   --bfile dataset.b37.outliers-updated
#   --chr 1
#   --out dataset.b37.outliers-updated-chr1
#   --recode vcf
#
# 257718 MB RAM detected; reserving 128859 MB for main workspace.
# 402326 out of 5436495 variants loaded from .bim file.
# 496 people (237 males, 259 females) loaded from .fam.
# 496 phenotype values loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 496 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.999986.
# --a1-allele: 402326 assignments made.
# 402326 variants and 496 people pass filters and QC.
# Among remaining phenotypes, 203 are cases and 293 are controls.
# --recode vcf to dataset.b37.outliers-updated-chr1.vcf ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b6.17 64-bit (28 Apr 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to dataset.b37.outliers-updated-chr2.log.
# Options in effect:
#   --a1-allele Force-Allele1-dataset.b37.outliers-HRC.txt
#   --bfile dataset.b37.outliers-updated
#   --chr 2
#   --out dataset.b37.outliers-updated-chr2
#   --recode vcf
#
# 257718 MB RAM detected; reserving 128859 MB for main workspace.
# 441697 out of 5436495 variants loaded from .bim file.
# 496 people (237 males, 259 females) loaded from .fam.
# 496 phenotype values loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 496 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.999984.
# --a1-allele: 441697 assignments made.
# 441697 variants and 496 people pass filters and QC.
# Among remaining phenotypes, 203 are cases and 293 are controls.
# --recode vcf to dataset.b37.outliers-updated-chr2.vcf ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b6.17 64-bit (28 Apr 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to dataset.b37.outliers-updated-chr3.log.
# Options in effect:
#   --a1-allele Force-Allele1-dataset.b37.outliers-HRC.txt
#   --bfile dataset.b37.outliers-updated
#   --chr 3
#   --out dataset.b37.outliers-updated-chr3
#   --recode vcf
#
# 257718 MB RAM detected; reserving 128859 MB for main workspace.
# 376451 out of 5436495 variants loaded from .bim file.
# 496 people (237 males, 259 females) loaded from .fam.
# 496 phenotype values loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 496 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.999982.
# --a1-allele: 376451 assignments made.
# 376451 variants and 496 people pass filters and QC.
# Among remaining phenotypes, 203 are cases and 293 are controls.
# --recode vcf to dataset.b37.outliers-updated-chr3.vcf ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b6.17 64-bit (28 Apr 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to dataset.b37.outliers-updated-chr4.log.
# Options in effect:
#   --a1-allele Force-Allele1-dataset.b37.outliers-HRC.txt
#   --bfile dataset.b37.outliers-updated
#   --chr 4
#   --out dataset.b37.outliers-updated-chr4
#   --recode vcf
#
# 257718 MB RAM detected; reserving 128859 MB for main workspace.
# 383874 out of 5436495 variants loaded from .bim file.
# 496 people (237 males, 259 females) loaded from .fam.
# 496 phenotype values loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 496 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.999982.
# --a1-allele: 383874 assignments made.
# 383874 variants and 496 people pass filters and QC.
# Among remaining phenotypes, 203 are cases and 293 are controls.
# --recode vcf to dataset.b37.outliers-updated-chr4.vcf ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b6.17 64-bit (28 Apr 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to dataset.b37.outliers-updated-chr5.log.
# Options in effect:
#   --a1-allele Force-Allele1-dataset.b37.outliers-HRC.txt
#   --bfile dataset.b37.outliers-updated
#   --chr 5
#   --out dataset.b37.outliers-updated-chr5
#   --recode vcf
#
# 257718 MB RAM detected; reserving 128859 MB for main workspace.
# 333822 out of 5436495 variants loaded from .bim file.
# 496 people (237 males, 259 females) loaded from .fam.
# 496 phenotype values loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 496 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.999984.
# --a1-allele: 333822 assignments made.
# 333822 variants and 496 people pass filters and QC.
# Among remaining phenotypes, 203 are cases and 293 are controls.
# --recode vcf to dataset.b37.outliers-updated-chr5.vcf ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b6.17 64-bit (28 Apr 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to dataset.b37.outliers-updated-chr6.log.
# Options in effect:
#   --a1-allele Force-Allele1-dataset.b37.outliers-HRC.txt
#   --bfile dataset.b37.outliers-updated
#   --chr 6
#   --out dataset.b37.outliers-updated-chr6
#   --recode vcf
#
# 257718 MB RAM detected; reserving 128859 MB for main workspace.
# 352662 out of 5436495 variants loaded from .bim file.
# 496 people (237 males, 259 females) loaded from .fam.
# 496 phenotype values loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 496 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.99998.
# --a1-allele: 352662 assignments made.
# 352662 variants and 496 people pass filters and QC.
# Among remaining phenotypes, 203 are cases and 293 are controls.
# --recode vcf to dataset.b37.outliers-updated-chr6.vcf ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b6.17 64-bit (28 Apr 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to dataset.b37.outliers-updated-chr7.log.
# Options in effect:
#   --a1-allele Force-Allele1-dataset.b37.outliers-HRC.txt
#   --bfile dataset.b37.outliers-updated
#   --chr 7
#   --out dataset.b37.outliers-updated-chr7
#   --recode vcf
#
# 257718 MB RAM detected; reserving 128859 MB for main workspace.
# 309668 out of 5436495 variants loaded from .bim file.
# 496 people (237 males, 259 females) loaded from .fam.
# 496 phenotype values loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 496 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.999984.
# --a1-allele: 309668 assignments made.
# 309668 variants and 496 people pass filters and QC.
# Among remaining phenotypes, 203 are cases and 293 are controls.
# --recode vcf to dataset.b37.outliers-updated-chr7.vcf ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b6.17 64-bit (28 Apr 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to dataset.b37.outliers-updated-chr8.log.
# Options in effect:
#   --a1-allele Force-Allele1-dataset.b37.outliers-HRC.txt
#   --bfile dataset.b37.outliers-updated
#   --chr 8
#   --out dataset.b37.outliers-updated-chr8
#   --recode vcf
#
# 257718 MB RAM detected; reserving 128859 MB for main workspace.
# 292233 out of 5436495 variants loaded from .bim file.
# 496 people (237 males, 259 females) loaded from .fam.
# 496 phenotype values loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 496 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.999982.
# --a1-allele: 292233 assignments made.
# 292233 variants and 496 people pass filters and QC.
# Among remaining phenotypes, 203 are cases and 293 are controls.
# --recode vcf to dataset.b37.outliers-updated-chr8.vcf ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b6.17 64-bit (28 Apr 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to dataset.b37.outliers-updated-chr9.log.
# Options in effect:
#   --a1-allele Force-Allele1-dataset.b37.outliers-HRC.txt
#   --bfile dataset.b37.outliers-updated
#   --chr 9
#   --out dataset.b37.outliers-updated-chr9
#   --recode vcf
#
# 257718 MB RAM detected; reserving 128859 MB for main workspace.
# 227584 out of 5436495 variants loaded from .bim file.
# 496 people (237 males, 259 females) loaded from .fam.
# 496 phenotype values loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 496 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.999988.
# --a1-allele: 227584 assignments made.
# 227584 variants and 496 people pass filters and QC.
# Among remaining phenotypes, 203 are cases and 293 are controls.
# --recode vcf to dataset.b37.outliers-updated-chr9.vcf ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b6.17 64-bit (28 Apr 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to dataset.b37.outliers-updated-chr10.log.
# Options in effect:
#   --a1-allele Force-Allele1-dataset.b37.outliers-HRC.txt
#   --bfile dataset.b37.outliers-updated
#   --chr 10
#   --out dataset.b37.outliers-updated-chr10
#   --recode vcf
#
# 257718 MB RAM detected; reserving 128859 MB for main workspace.
# 273118 out of 5436495 variants loaded from .bim file.
# 496 people (237 males, 259 females) loaded from .fam.
# 496 phenotype values loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 496 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.999989.
# --a1-allele: 273118 assignments made.
# 273118 variants and 496 people pass filters and QC.
# Among remaining phenotypes, 203 are cases and 293 are controls.
# --recode vcf to dataset.b37.outliers-updated-chr10.vcf ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b6.17 64-bit (28 Apr 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to dataset.b37.outliers-updated-chr11.log.
# Options in effect:
#   --a1-allele Force-Allele1-dataset.b37.outliers-HRC.txt
#   --bfile dataset.b37.outliers-updated
#   --chr 11
#   --out dataset.b37.outliers-updated-chr11
#   --recode vcf
#
# 257718 MB RAM detected; reserving 128859 MB for main workspace.
# 265922 out of 5436495 variants loaded from .bim file.
# 496 people (237 males, 259 females) loaded from .fam.
# 496 phenotype values loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 496 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.999987.
# --a1-allele: 265922 assignments made.
# 265922 variants and 496 people pass filters and QC.
# Among remaining phenotypes, 203 are cases and 293 are controls.
# --recode vcf to dataset.b37.outliers-updated-chr11.vcf ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b6.17 64-bit (28 Apr 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to dataset.b37.outliers-updated-chr12.log.
# Options in effect:
#   --a1-allele Force-Allele1-dataset.b37.outliers-HRC.txt
#   --bfile dataset.b37.outliers-updated
#   --chr 12
#   --out dataset.b37.outliers-updated-chr12
#   --recode vcf
#
# 257718 MB RAM detected; reserving 128859 MB for main workspace.
# 254015 out of 5436495 variants loaded from .bim file.
# 496 people (237 males, 259 females) loaded from .fam.
# 496 phenotype values loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 496 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.999989.
# --a1-allele: 254015 assignments made.
# 254015 variants and 496 people pass filters and QC.
# Among remaining phenotypes, 203 are cases and 293 are controls.
# --recode vcf to dataset.b37.outliers-updated-chr12.vcf ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b6.17 64-bit (28 Apr 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to dataset.b37.outliers-updated-chr13.log.
# Options in effect:
#   --a1-allele Force-Allele1-dataset.b37.outliers-HRC.txt
#   --bfile dataset.b37.outliers-updated
#   --chr 13
#   --out dataset.b37.outliers-updated-chr13
#   --recode vcf
#
# 257718 MB RAM detected; reserving 128859 MB for main workspace.
# 198466 out of 5436495 variants loaded from .bim file.
# 496 people (237 males, 259 females) loaded from .fam.
# 496 phenotype values loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 496 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.999987.
# --a1-allele: 198466 assignments made.
# 198466 variants and 496 people pass filters and QC.
# Among remaining phenotypes, 203 are cases and 293 are controls.
# --recode vcf to dataset.b37.outliers-updated-chr13.vcf ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b6.17 64-bit (28 Apr 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to dataset.b37.outliers-updated-chr14.log.
# Options in effect:
#   --a1-allele Force-Allele1-dataset.b37.outliers-HRC.txt
#   --bfile dataset.b37.outliers-updated
#   --chr 14
#   --out dataset.b37.outliers-updated-chr14
#   --recode vcf
#
# 257718 MB RAM detected; reserving 128859 MB for main workspace.
# 173038 out of 5436495 variants loaded from .bim file.
# 496 people (237 males, 259 females) loaded from .fam.
# 496 phenotype values loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 496 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.999985.
# --a1-allele: 173038 assignments made.
# 173038 variants and 496 people pass filters and QC.
# Among remaining phenotypes, 203 are cases and 293 are controls.
# --recode vcf to dataset.b37.outliers-updated-chr14.vcf ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b6.17 64-bit (28 Apr 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to dataset.b37.outliers-updated-chr15.log.
# Options in effect:
#   --a1-allele Force-Allele1-dataset.b37.outliers-HRC.txt
#   --bfile dataset.b37.outliers-updated
#   --chr 15
#   --out dataset.b37.outliers-updated-chr15
#   --recode vcf
#
# 257718 MB RAM detected; reserving 128859 MB for main workspace.
# 149280 out of 5436495 variants loaded from .bim file.
# 496 people (237 males, 259 females) loaded from .fam.
# 496 phenotype values loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 496 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.99999.
# --a1-allele: 149280 assignments made.
# 149280 variants and 496 people pass filters and QC.
# Among remaining phenotypes, 203 are cases and 293 are controls.
# --recode vcf to dataset.b37.outliers-updated-chr15.vcf ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b6.17 64-bit (28 Apr 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to dataset.b37.outliers-updated-chr16.log.
# Options in effect:
#   --a1-allele Force-Allele1-dataset.b37.outliers-HRC.txt
#   --bfile dataset.b37.outliers-updated
#   --chr 16
#   --out dataset.b37.outliers-updated-chr16
#   --recode vcf
#
# 257718 MB RAM detected; reserving 128859 MB for main workspace.
# 162069 out of 5436495 variants loaded from .bim file.
# 496 people (237 males, 259 females) loaded from .fam.
# 496 phenotype values loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 496 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.999977.
# --a1-allele: 162069 assignments made.
# 162069 variants and 496 people pass filters and QC.
# Among remaining phenotypes, 203 are cases and 293 are controls.
# --recode vcf to dataset.b37.outliers-updated-chr16.vcf ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b6.17 64-bit (28 Apr 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to dataset.b37.outliers-updated-chr17.log.
# Options in effect:
#   --a1-allele Force-Allele1-dataset.b37.outliers-HRC.txt
#   --bfile dataset.b37.outliers-updated
#   --chr 17
#   --out dataset.b37.outliers-updated-chr17
#   --recode vcf
#
# 257718 MB RAM detected; reserving 128859 MB for main workspace.
# 140234 out of 5436495 variants loaded from .bim file.
# 496 people (237 males, 259 females) loaded from .fam.
# 496 phenotype values loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 496 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.999993.
# --a1-allele: 140234 assignments made.
# 140234 variants and 496 people pass filters and QC.
# Among remaining phenotypes, 203 are cases and 293 are controls.
# --recode vcf to dataset.b37.outliers-updated-chr17.vcf ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b6.17 64-bit (28 Apr 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to dataset.b37.outliers-updated-chr18.log.
# Options in effect:
#   --a1-allele Force-Allele1-dataset.b37.outliers-HRC.txt
#   --bfile dataset.b37.outliers-updated
#   --chr 18
#   --out dataset.b37.outliers-updated-chr18
#   --recode vcf
#
# 257718 MB RAM detected; reserving 128859 MB for main workspace.
# 152524 out of 5436495 variants loaded from .bim file.
# 496 people (237 males, 259 females) loaded from .fam.
# 496 phenotype values loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 496 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.999983.
# --a1-allele: 152524 assignments made.
# 152524 variants and 496 people pass filters and QC.
# Among remaining phenotypes, 203 are cases and 293 are controls.
# --recode vcf to dataset.b37.outliers-updated-chr18.vcf ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b6.17 64-bit (28 Apr 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to dataset.b37.outliers-updated-chr19.log.
# Options in effect:
#   --a1-allele Force-Allele1-dataset.b37.outliers-HRC.txt
#   --bfile dataset.b37.outliers-updated
#   --chr 19
#   --out dataset.b37.outliers-updated-chr19
#   --recode vcf
#
# 257718 MB RAM detected; reserving 128859 MB for main workspace.
# 119631 out of 5436495 variants loaded from .bim file.
# 496 people (237 males, 259 females) loaded from .fam.
# 496 phenotype values loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 496 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.999985.
# --a1-allele: 119631 assignments made.
# 119631 variants and 496 people pass filters and QC.
# Among remaining phenotypes, 203 are cases and 293 are controls.
# --recode vcf to dataset.b37.outliers-updated-chr19.vcf ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b6.17 64-bit (28 Apr 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to dataset.b37.outliers-updated-chr20.log.
# Options in effect:
#   --a1-allele Force-Allele1-dataset.b37.outliers-HRC.txt
#   --bfile dataset.b37.outliers-updated
#   --chr 20
#   --out dataset.b37.outliers-updated-chr20
#   --recode vcf
#
# 257718 MB RAM detected; reserving 128859 MB for main workspace.
# 119733 out of 5436495 variants loaded from .bim file.
# 496 people (237 males, 259 females) loaded from .fam.
# 496 phenotype values loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 496 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.999981.
# --a1-allele: 119733 assignments made.
# 119733 variants and 496 people pass filters and QC.
# Among remaining phenotypes, 203 are cases and 293 are controls.
# --recode vcf to dataset.b37.outliers-updated-chr20.vcf ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b6.17 64-bit (28 Apr 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to dataset.b37.outliers-updated-chr21.log.
# Options in effect:
#   --a1-allele Force-Allele1-dataset.b37.outliers-HRC.txt
#   --bfile dataset.b37.outliers-updated
#   --chr 21
#   --out dataset.b37.outliers-updated-chr21
#   --recode vcf
#
# 257718 MB RAM detected; reserving 128859 MB for main workspace.
# 76336 out of 5436495 variants loaded from .bim file.
# 496 people (237 males, 259 females) loaded from .fam.
# 496 phenotype values loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 496 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.999982.
# --a1-allele: 76336 assignments made.
# 76336 variants and 496 people pass filters and QC.
# Among remaining phenotypes, 203 are cases and 293 are controls.
# --recode vcf to dataset.b37.outliers-updated-chr21.vcf ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b6.17 64-bit (28 Apr 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to dataset.b37.outliers-updated-chr22.log.
# Options in effect:
#   --a1-allele Force-Allele1-dataset.b37.outliers-HRC.txt
#   --bfile dataset.b37.outliers-updated
#   --chr 22
#   --out dataset.b37.outliers-updated-chr22
#   --recode vcf
#
# 257718 MB RAM detected; reserving 128859 MB for main workspace.
# 72255 out of 5436495 variants loaded from .bim file.
# 496 people (237 males, 259 females) loaded from .fam.
# 496 phenotype values loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 496 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.999977.
# --a1-allele: 72255 assignments made.
# 72255 variants and 496 people pass filters and QC.
# Among remaining phenotypes, 203 are cases and 293 are controls.
# --recode vcf to dataset.b37.outliers-updated-chr22.vcf ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b6.17 64-bit (28 Apr 2020)          www.cog-genomics.org/plink/1.9/
# (C) 2005-2020 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to dataset.b37.outliers-updated-chr23.log.
# Options in effect:
#   --a1-allele Force-Allele1-dataset.b37.outliers-HRC.txt
#   --bfile dataset.b37.outliers-updated
#   --chr 23
#   --out dataset.b37.outliers-updated-chr23
#   --recode vcf
#
# 257718 MB RAM detected; reserving 128859 MB for main workspace.
# 159557 out of 5436495 variants loaded from .bim file.
# 496 people (237 males, 259 females) loaded from .fam.
# 496 phenotype values loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 496 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.999997.
# --a1-allele: 159557 assignments made.
# 159557 variants and 496 people pass filters and QC.
# Among remaining phenotypes, 203 are cases and 293 are controls.
# --recode vcf to dataset.b37.outliers-updated-chr23.vcf ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.

# %%
# %%bash
# # compress the vcf files to upload to Michigan Server
# for i in {1..22}
# do
#     vcf-sort $path/dataset.b37.outliers-updated-chr$i.vcf | bgzip -c > $path/dataset.b37-sorted-chr$i.vcf.gz
# done
# Out:
# sort -k1,1d -k2,2n
# sort -k1,1d -k2,2n
# sort -k1,1d -k2,2n
# sort -k1,1d -k2,2n
# sort -k1,1d -k2,2n
# sort -k1,1d -k2,2n
# sort -k1,1d -k2,2n
# sort -k1,1d -k2,2n
# sort -k1,1d -k2,2n
# sort -k1,1d -k2,2n
# sort -k1,1d -k2,2n
# sort -k1,1d -k2,2n
# sort -k1,1d -k2,2n
# sort -k1,1d -k2,2n
# sort -k1,1d -k2,2n
# sort -k1,1d -k2,2n
# sort -k1,1d -k2,2n
# sort -k1,1d -k2,2n
# sort -k1,1d -k2,2n
# sort -k1,1d -k2,2n
# sort -k1,1d -k2,2n
# sort -k1,1d -k2,2n

# %% [markdown]
# ## Upload vcf.gz files to the Michigan server (phasing: SHAPE-IT; reference:HRC; mode: QC&imputation)
#
# Log into the Michigan Imputation Server site and click on Run -> Michigan Imputation Server from the menu located at the top.
#
# Select HRC r1.1 2016 reference panel, GRCh37/hg19 array built, 0.3 rsq filter, Eagle v2.4 as the phasing algoruthm, EUR population and "Quality control& Imputation" as the mode; you can also selecet AES 256 encryption. Upload vcf.gz files generated in the previous step and wait for a succesfull upload and initial QC.
#
# You will receive an email when the job is completed with the link and paswword to access the results. Download them.

# %% [markdown]
# ## QC of the imputed genotypes

# %%
# %%bash
# # Unzip the chromosomes files. Provide the password (in double quotes) supplied by the Michigan server
# for i in {1..22}
# do
# unzip -P "HOfK3mXPunr4Xl" $path/imputed_files/chr_$i.zip -d $path/imputed_files
# done
# Out:
# Archive:  /mnt/data/GWAS/output/task3_imputation/imputed_files/chr_1.zip
#   inflating: /mnt/data/GWAS/output/task3_imputation/imputed_files/chr1.dose.vcf.gz
#   inflating: /mnt/data/GWAS/output/task3_imputation/imputed_files/chr1.info.gz
# Archive:  /mnt/data/GWAS/output/task3_imputation/imputed_files/chr_2.zip
#   inflating: /mnt/data/GWAS/output/task3_imputation/imputed_files/chr2.dose.vcf.gz
#   inflating: /mnt/data/GWAS/output/task3_imputation/imputed_files/chr2.info.gz
# Archive:  /mnt/data/GWAS/output/task3_imputation/imputed_files/chr_3.zip
#   inflating: /mnt/data/GWAS/output/task3_imputation/imputed_files/chr3.dose.vcf.gz
#   inflating: /mnt/data/GWAS/output/task3_imputation/imputed_files/chr3.info.gz
# Archive:  /mnt/data/GWAS/output/task3_imputation/imputed_files/chr_4.zip
#   inflating: /mnt/data/GWAS/output/task3_imputation/imputed_files/chr4.dose.vcf.gz
#   inflating: /mnt/data/GWAS/output/task3_imputation/imputed_files/chr4.info.gz
# Archive:  /mnt/data/GWAS/output/task3_imputation/imputed_files/chr_5.zip
#   inflating: /mnt/data/GWAS/output/task3_imputation/imputed_files/chr5.dose.vcf.gz
#   inflating: /mnt/data/GWAS/output/task3_imputation/imputed_files/chr5.info.gz
# Archive:  /mnt/data/GWAS/output/task3_imputation/imputed_files/chr_6.zip
#   inflating: /mnt/data/GWAS/output/task3_imputation/imputed_files/chr6.dose.vcf.gz
#   inflating: /mnt/data/GWAS/output/task3_imputation/imputed_files/chr6.info.gz
# Archive:  /mnt/data/GWAS/output/task3_imputation/imputed_files/chr_7.zip
#   inflating: /mnt/data/GWAS/output/task3_imputation/imputed_files/chr7.dose.vcf.gz
#   inflating: /mnt/data/GWAS/output/task3_imputation/imputed_files/chr7.info.gz
# Archive:  /mnt/data/GWAS/output/task3_imputation/imputed_files/chr_8.zip
#   inflating: /mnt/data/GWAS/output/task3_imputation/imputed_files/chr8.dose.vcf.gz
#   inflating: /mnt/data/GWAS/output/task3_imputation/imputed_files/chr8.info.gz
# Archive:  /mnt/data/GWAS/output/task3_imputation/imputed_files/chr_9.zip
#   inflating: /mnt/data/GWAS/output/task3_imputation/imputed_files/chr9.dose.vcf.gz
#   inflating: /mnt/data/GWAS/output/task3_imputation/imputed_files/chr9.info.gz
# Archive:  /mnt/data/GWAS/output/task3_imputation/imputed_files/chr_10.zip
#   inflating: /mnt/data/GWAS/output/task3_imputation/imputed_files/chr10.dose.vcf.gz
#   inflating: /mnt/data/GWAS/output/task3_imputation/imputed_files/chr10.info.gz
# Archive:  /mnt/data/GWAS/output/task3_imputation/imputed_files/chr_11.zip
#   inflating: /mnt/data/GWAS/output/task3_imputation/imputed_files/chr11.dose.vcf.gz
#   inflating: /mnt/data/GWAS/output/task3_imputation/imputed_files/chr11.info.gz
# Archive:  /mnt/data/GWAS/output/task3_imputation/imputed_files/chr_12.zip
#   inflating: /mnt/data/GWAS/output/task3_imputation/imputed_files/chr12.dose.vcf.gz
#   inflating: /mnt/data/GWAS/output/task3_imputation/imputed_files/chr12.info.gz
# Archive:  /mnt/data/GWAS/output/task3_imputation/imputed_files/chr_13.zip
#   inflating: /mnt/data/GWAS/output/task3_imputation/imputed_files/chr13.dose.vcf.gz
#   inflating: /mnt/data/GWAS/output/task3_imputation/imputed_files/chr13.info.gz
# Archive:  /mnt/data/GWAS/output/task3_imputation/imputed_files/chr_14.zip
#   inflating: /mnt/data/GWAS/output/task3_imputation/imputed_files/chr14.dose.vcf.gz
#   inflating: /mnt/data/GWAS/output/task3_imputation/imputed_files/chr14.info.gz
# Archive:  /mnt/data/GWAS/output/task3_imputation/imputed_files/chr_15.zip
#   inflating: /mnt/data/GWAS/output/task3_imputation/imputed_files/chr15.dose.vcf.gz
#   inflating: /mnt/data/GWAS/output/task3_imputation/imputed_files/chr15.info.gz
# Archive:  /mnt/data/GWAS/output/task3_imputation/imputed_files/chr_16.zip
#   inflating: /mnt/data/GWAS/output/task3_imputation/imputed_files/chr16.dose.vcf.gz
#   inflating: /mnt/data/GWAS/output/task3_imputation/imputed_files/chr16.info.gz
# Archive:  /mnt/data/GWAS/output/task3_imputation/imputed_files/chr_17.zip
#   inflating: /mnt/data/GWAS/output/task3_imputation/imputed_files/chr17.dose.vcf.gz
#   inflating: /mnt/data/GWAS/output/task3_imputation/imputed_files/chr17.info.gz
# Archive:  /mnt/data/GWAS/output/task3_imputation/imputed_files/chr_18.zip
#   inflating: /mnt/data/GWAS/output/task3_imputation/imputed_files/chr18.dose.vcf.gz
#   inflating: /mnt/data/GWAS/output/task3_imputation/imputed_files/chr18.info.gz
# Archive:  /mnt/data/GWAS/output/task3_imputation/imputed_files/chr_19.zip
#   inflating: /mnt/data/GWAS/output/task3_imputation/imputed_files/chr19.dose.vcf.gz
#   inflating: /mnt/data/GWAS/output/task3_imputation/imputed_files/chr19.info.gz
# Archive:  /mnt/data/GWAS/output/task3_imputation/imputed_files/chr_20.zip
#   inflating: /mnt/data/GWAS/output/task3_imputation/imputed_files/chr20.dose.vcf.gz
#   inflating: /mnt/data/GWAS/output/task3_imputation/imputed_files/chr20.info.gz
# Archive:  /mnt/data/GWAS/output/task3_imputation/imputed_files/chr_21.zip
#   inflating: /mnt/data/GWAS/output/task3_imputation/imputed_files/chr21.dose.vcf.gz
#   inflating: /mnt/data/GWAS/output/task3_imputation/imputed_files/chr21.info.gz
# Archive:  /mnt/data/GWAS/output/task3_imputation/imputed_files/chr_22.zip
#   inflating: /mnt/data/GWAS/output/task3_imputation/imputed_files/chr22.dose.vcf.gz
#   inflating: /mnt/data/GWAS/output/task3_imputation/imputed_files/chr22.info.gz

# %% [markdown]
#  **Extract genotype doses**

# %%
# %%bash
# # Extract genotype doses from vcf files and generate dosage files for PLINK software.
# # 1st parameter: path to extracted zip files (from previous step). Output files will be stored in this path
# # 2nd parameter: boolean indicating whereas the rsquare filter was applied during imputation
# bash scripts/extract_dose.sh $path/imputed_files true

# %% [markdown]
# **Generate a .fam file for PLINK from the chr22 vcf. Then update sex and pheno with the QCed fam from task 2.2 (i.e. dataset.b37.outliers)**

# %%
# %%bash
# plink --vcf $path/imputed_files/chr22.dose.vcf.gz --make-bed --out $path/imputed_files/chr22.dose
# Out:
# PLINK v1.90b3.45 64-bit (13 Jan 2017)      https://www.cog-genomics.org/plink2
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /mnt/data/GWAS/output/task3_imputation/imputed_files/chr22.dose.log.
# Options in effect:
#   --make-bed
#   --out /mnt/data/GWAS/output/task3_imputation/imputed_files/chr22.dose
#   --vcf /mnt/data/GWAS/output/task3_imputation/imputed_files/chr22.dose.vcf.gz
#
# 32127 MB RAM detected; reserving 16063 MB for main workspace.
# --vcf: 218k variants complete.
# /mnt/data/GWAS/output/task3_imputation/imputed_files/chr22.dose-temporary.bed +
# /mnt/data/GWAS/output/task3_imputation/imputed_files/chr22.dose-temporary.bim +
# /mnt/data/GWAS/output/task3_imputation/imputed_files/chr22.dose-temporary.fam
# written.
# 218642 variants loaded from .bim file.
# 496 people (0 males, 0 females, 496 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# /mnt/data/GWAS/output/task3_imputation/imputed_files/chr22.dose.nosex .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 496 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# 218642 variants and 496 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to
# /mnt/data/GWAS/output/task3_imputation/imputed_files/chr22.dose.bed +
# /mnt/data/GWAS/output/task3_imputation/imputed_files/chr22.dose.bim +
# /mnt/data/GWAS/output/task3_imputation/imputed_files/chr22.dose.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.

# %%
# %%bash
# head $path/imputed_files/chr22.dose.fam
# Out:
# HGX00096 HGX00096 0 0 0 -9
# HGX00097 HGX00097 0 0 0 -9
# HGX00099 HGX00099 0 0 0 -9
# HGX00100 HGX00100 0 0 0 -9
# HGX00101 HGX00101 0 0 0 -9
# HGX00102 HGX00102 0 0 0 -9
# HGX00103 HGX00103 0 0 0 -9
# HGX00105 HGX00105 0 0 0 -9
# HGX00106 HGX00106 0 0 0 -9
# HGX00107 HGX00107 0 0 0 -9

# %%
# %%bash
# plink --bfile $path/imputed_files/chr22.dose --make-bed --update-sex /mnt/data/GWAS/output/task2.2_stratification/intermediate_datasets/dataset.b37.outliers.fam 3 --pheno /mnt/data/GWAS/output/task2.2_stratification/intermediate_datasets/dataset.b37.outliers.fam --mpheno 4 --out  $path/imputed_files/chr22.dose.for.assoc
# Out:
# PLINK v1.90b3.45 64-bit (13 Jan 2017)      https://www.cog-genomics.org/plink2
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /mnt/data/GWAS/output/task3_imputation/imputed_files/chr22.dose.for.assoc.log.
# Options in effect:
#   --bfile /mnt/data/GWAS/output/task3_imputation/imputed_files/chr22.dose
#   --make-bed
#   --mpheno 4
#   --out /mnt/data/GWAS/output/task3_imputation/imputed_files/chr22.dose.for.assoc
#   --pheno /mnt/data/GWAS/output/task2.2_stratification/intermediate_datasets/dataset.b37.outliers.fam
#   --update-sex /mnt/data/GWAS/output/task2.2_stratification/intermediate_datasets/dataset.b37.outliers.fam 3
#
# 32127 MB RAM detected; reserving 16063 MB for main workspace.
# 218642 variants loaded from .bim file.
# 496 people (0 males, 0 females, 496 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# /mnt/data/GWAS/output/task3_imputation/imputed_files/chr22.dose.for.assoc.nosex
# .
# 496 phenotype values present after --pheno.
# --update-sex: 496 people updated.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 496 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# 218642 variants and 496 people pass filters and QC.
# Among remaining phenotypes, 203 are cases and 293 are controls.
# --make-bed to
# /mnt/data/GWAS/output/task3_imputation/imputed_files/chr22.dose.for.assoc.bed +
# /mnt/data/GWAS/output/task3_imputation/imputed_files/chr22.dose.for.assoc.bim +
# /mnt/data/GWAS/output/task3_imputation/imputed_files/chr22.dose.for.assoc.fam
# ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.

# %%
# %%bash
# head $path/imputed_files/chr22.dose.for.assoc.fam
# Out:
# HGX00096 HGX00096 0 0 1 1
# HGX00097 HGX00097 0 0 2 1
# HGX00099 HGX00099 0 0 2 1
# HGX00100 HGX00100 0 0 2 1
# HGX00101 HGX00101 0 0 1 1
# HGX00102 HGX00102 0 0 2 1
# HGX00103 HGX00103 0 0 1 1
# HGX00105 HGX00105 0 0 1 1
# HGX00106 HGX00106 0 0 2 1
# HGX00107 HGX00107 0 0 1 1

# %%
# %%bash
# rm $path/imputed_files/chr22.dose.fam

# %% [markdown]
# **For the next step you need the following files:**
# - chr22.dose.for.assoc.fam
# - chri.dose.rsq.DS.vcf.gz
