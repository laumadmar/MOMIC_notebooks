# %% [markdown]
# # 1000 Genome data preparation
#
# Data from the 1000 Genomes Project need to be processed before used for population stratification. This dataset after QC is provided, there is no need to run these first steps.
#
# To complete this task it is necessary to have generated the bfile 'dataset.b37_IBD' from the previous tutorial (Task_2_QC).

# %%
# %env path= /mnt/data/GWAS/output/task2.2_stratification
# %env intpath=/mnt/data/GWAS/output/task2.2_stratification/intermediate_datasets
# %env ref_files=/mnt/data/GWAS/ref_files/Phase3_v5
# Out:
# env: path=/mnt/data/GWAS/output/task2.2_stratification
# env: intpath=/mnt/data/GWAS/output/task2.2_stratification/intermediate_datasets

# %%
# %%bash
# # Get a list of SNPs from your working dataset
# awk '{print $2}' /mnt/data/GWAS/output/task2_QC/intermediate_datasets/dataset.b37.IBD.bim > $path/mySNPlist.txt
# head $path/mySNPlist.txt
# Out:
# 1:10177
# 1:11008
# 1:11012
# 1:13110
# rs201725126
# rs200579949
# 1:13273
# 1:14464
# 1:14599
# 1:14604

# %%
# %%bash
# # Creates a recode vcf per chromosome, using as input 1000 Genomes compressed vcf file per chr and previous SNPs list.
# # Then plink converts them to bfiles.
# for i in {1..22}
# do
# vcftools --gzvcf $ref_files/ALL.chr$i.phase3_shapeit2_mvncall_integrated_v5a.20130502.genotypes.clean.vcf.gz --snps $path/mySNPlist.txt --recode --out $path/1KG.vcf.chr$i
# plink --vcf $path/1KG.vcf.chr$i.recode.vcf --make-bed --out $path/1KG.chr$i
# rm $path/1KG.vcf.chr$i.recode.vcf
# done
# Out:
# PLINK v1.90b3.45 64-bit (13 Jan 2017)      https://www.cog-genomics.org/plink2
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /mnt/data/GWAS/output/task2.2_stratification//1KG.chr1.log.
# Options in effect:
#   --make-bed
#   --out /mnt/data/GWAS/output/task2.2_stratification//1KG.chr1
#   --vcf /mnt/data/GWAS/output/task2.2_stratification//1KG.vcf.chr1.recode.vcf
#
# 32127 MB RAM detected; reserving 16063 MB for main workspace.
# --vcf: /mnt/data/GWAS/output/task2.2_stratification//1KG.chr1-temporary.bed +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr1-temporary.bim +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr1-temporary.fam written.
# 497923 variants loaded from .bim file.
# 2504 people (0 males, 0 females, 2504 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr1.nosex .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 2504 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.999861.
# 497923 variants and 2504 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to /mnt/data/GWAS/output/task2.2_stratification//1KG.chr1.bed +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr1.bim +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr1.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b3.45 64-bit (13 Jan 2017)      https://www.cog-genomics.org/plink2
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /mnt/data/GWAS/output/task2.2_stratification//1KG.chr2.log.
# Options in effect:
#   --make-bed
#   --out /mnt/data/GWAS/output/task2.2_stratification//1KG.chr2
#   --vcf /mnt/data/GWAS/output/task2.2_stratification//1KG.vcf.chr2.recode.vcf
#
# 32127 MB RAM detected; reserving 16063 MB for main workspace.
# --vcf: /mnt/data/GWAS/output/task2.2_stratification//1KG.chr2-temporary.bed +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr2-temporary.bim +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr2-temporary.fam written.
# 540431 variants loaded from .bim file.
# 2504 people (0 males, 0 females, 2504 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr2.nosex .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 2504 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.999857.
# 540431 variants and 2504 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to /mnt/data/GWAS/output/task2.2_stratification//1KG.chr2.bed +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr2.bim +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr2.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b3.45 64-bit (13 Jan 2017)      https://www.cog-genomics.org/plink2
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /mnt/data/GWAS/output/task2.2_stratification//1KG.chr3.log.
# Options in effect:
#   --make-bed
#   --out /mnt/data/GWAS/output/task2.2_stratification//1KG.chr3
#   --vcf /mnt/data/GWAS/output/task2.2_stratification//1KG.vcf.chr3.recode.vcf
#
# 32127 MB RAM detected; reserving 16063 MB for main workspace.
# --vcf: /mnt/data/GWAS/output/task2.2_stratification//1KG.chr3-temporary.bed +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr3-temporary.bim +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr3-temporary.fam written.
# 462062 variants loaded from .bim file.
# 2504 people (0 males, 0 females, 2504 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr3.nosex .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 2504 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.999848.
# 462062 variants and 2504 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to /mnt/data/GWAS/output/task2.2_stratification//1KG.chr3.bed +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr3.bim +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr3.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b3.45 64-bit (13 Jan 2017)      https://www.cog-genomics.org/plink2
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /mnt/data/GWAS/output/task2.2_stratification//1KG.chr4.log.
# Options in effect:
#   --make-bed
#   --out /mnt/data/GWAS/output/task2.2_stratification//1KG.chr4
#   --vcf /mnt/data/GWAS/output/task2.2_stratification//1KG.vcf.chr4.recode.vcf
#
# 32127 MB RAM detected; reserving 16063 MB for main workspace.
# --vcf: /mnt/data/GWAS/output/task2.2_stratification//1KG.chr4-temporary.bed +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr4-temporary.bim +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr4-temporary.fam written.
# 474260 variants loaded from .bim file.
# 2504 people (0 males, 0 females, 2504 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr4.nosex .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 2504 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.999847.
# 474260 variants and 2504 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to /mnt/data/GWAS/output/task2.2_stratification//1KG.chr4.bed +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr4.bim +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr4.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b3.45 64-bit (13 Jan 2017)      https://www.cog-genomics.org/plink2
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /mnt/data/GWAS/output/task2.2_stratification//1KG.chr5.log.
# Options in effect:
#   --make-bed
#   --out /mnt/data/GWAS/output/task2.2_stratification//1KG.chr5
#   --vcf /mnt/data/GWAS/output/task2.2_stratification//1KG.vcf.chr5.recode.vcf
#
# 32127 MB RAM detected; reserving 16063 MB for main workspace.
# --vcf: /mnt/data/GWAS/output/task2.2_stratification//1KG.chr5-temporary.bed +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr5-temporary.bim +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr5-temporary.fam written.
# 410091 variants loaded from .bim file.
# 2504 people (0 males, 0 females, 2504 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr5.nosex .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 2504 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.999849.
# 410091 variants and 2504 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to /mnt/data/GWAS/output/task2.2_stratification//1KG.chr5.bed +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr5.bim +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr5.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b3.45 64-bit (13 Jan 2017)      https://www.cog-genomics.org/plink2
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /mnt/data/GWAS/output/task2.2_stratification//1KG.chr6.log.
# Options in effect:
#   --make-bed
#   --out /mnt/data/GWAS/output/task2.2_stratification//1KG.chr6
#   --vcf /mnt/data/GWAS/output/task2.2_stratification//1KG.vcf.chr6.recode.vcf
#
# 32127 MB RAM detected; reserving 16063 MB for main workspace.
# --vcf: /mnt/data/GWAS/output/task2.2_stratification//1KG.chr6-temporary.bed +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr6-temporary.bim +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr6-temporary.fam written.
# 440932 variants loaded from .bim file.
# 2504 people (0 males, 0 females, 2504 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr6.nosex .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 2504 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.999843.
# 440932 variants and 2504 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to /mnt/data/GWAS/output/task2.2_stratification//1KG.chr6.bed +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr6.bim +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr6.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b3.45 64-bit (13 Jan 2017)      https://www.cog-genomics.org/plink2
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /mnt/data/GWAS/output/task2.2_stratification//1KG.chr7.log.
# Options in effect:
#   --make-bed
#   --out /mnt/data/GWAS/output/task2.2_stratification//1KG.chr7
#   --vcf /mnt/data/GWAS/output/task2.2_stratification//1KG.vcf.chr7.recode.vcf
#
# 32127 MB RAM detected; reserving 16063 MB for main workspace.
# --vcf: /mnt/data/GWAS/output/task2.2_stratification//1KG.chr7-temporary.bed +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr7-temporary.bim +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr7-temporary.fam written.
# 384634 variants loaded from .bim file.
# 2504 people (0 males, 0 females, 2504 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr7.nosex .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 2504 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.999854.
# 384634 variants and 2504 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to /mnt/data/GWAS/output/task2.2_stratification//1KG.chr7.bed +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr7.bim +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr7.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b3.45 64-bit (13 Jan 2017)      https://www.cog-genomics.org/plink2
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /mnt/data/GWAS/output/task2.2_stratification//1KG.chr8.log.
# Options in effect:
#   --make-bed
#   --out /mnt/data/GWAS/output/task2.2_stratification//1KG.chr8
#   --vcf /mnt/data/GWAS/output/task2.2_stratification//1KG.vcf.chr8.recode.vcf
#
# 32127 MB RAM detected; reserving 16063 MB for main workspace.
# --vcf: /mnt/data/GWAS/output/task2.2_stratification//1KG.chr8-temporary.bed +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr8-temporary.bim +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr8-temporary.fam written.
# 354504 variants loaded from .bim file.
# 2504 people (0 males, 0 females, 2504 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr8.nosex .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 2504 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.999832.
# 354504 variants and 2504 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to /mnt/data/GWAS/output/task2.2_stratification//1KG.chr8.bed +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr8.bim +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr8.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b3.45 64-bit (13 Jan 2017)      https://www.cog-genomics.org/plink2
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /mnt/data/GWAS/output/task2.2_stratification//1KG.chr9.log.
# Options in effect:
#   --make-bed
#   --out /mnt/data/GWAS/output/task2.2_stratification//1KG.chr9
#   --vcf /mnt/data/GWAS/output/task2.2_stratification//1KG.vcf.chr9.recode.vcf
#
# 32127 MB RAM detected; reserving 16063 MB for main workspace.
# --vcf: /mnt/data/GWAS/output/task2.2_stratification//1KG.chr9-temporary.bed +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr9-temporary.bim +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr9-temporary.fam written.
# 281556 variants loaded from .bim file.
# 2504 people (0 males, 0 females, 2504 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr9.nosex .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 2504 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.999837.
# 281556 variants and 2504 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to /mnt/data/GWAS/output/task2.2_stratification//1KG.chr9.bed +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr9.bim +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr9.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b3.45 64-bit (13 Jan 2017)      https://www.cog-genomics.org/plink2
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /mnt/data/GWAS/output/task2.2_stratification//1KG.chr10.log.
# Options in effect:
#   --make-bed
#   --out /mnt/data/GWAS/output/task2.2_stratification//1KG.chr10
#   --vcf /mnt/data/GWAS/output/task2.2_stratification//1KG.vcf.chr10.recode.vcf
#
# 32127 MB RAM detected; reserving 16063 MB for main workspace.
# --vcf: /mnt/data/GWAS/output/task2.2_stratification//1KG.chr10-temporary.bed +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr10-temporary.bim +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr10-temporary.fam written.
# 336853 variants loaded from .bim file.
# 2504 people (0 males, 0 females, 2504 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr10.nosex .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 2504 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.999856.
# 336853 variants and 2504 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to /mnt/data/GWAS/output/task2.2_stratification//1KG.chr10.bed +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr10.bim +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr10.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b3.45 64-bit (13 Jan 2017)      https://www.cog-genomics.org/plink2
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /mnt/data/GWAS/output/task2.2_stratification//1KG.chr11.log.
# Options in effect:
#   --make-bed
#   --out /mnt/data/GWAS/output/task2.2_stratification//1KG.chr11
#   --vcf /mnt/data/GWAS/output/task2.2_stratification//1KG.vcf.chr11.recode.vcf
#
# 32127 MB RAM detected; reserving 16063 MB for main workspace.
# --vcf: /mnt/data/GWAS/output/task2.2_stratification//1KG.chr11-temporary.bed +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr11-temporary.bim +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr11-temporary.fam written.
# 328068 variants loaded from .bim file.
# 2504 people (0 males, 0 females, 2504 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr11.nosex .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 2504 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.999851.
# 328068 variants and 2504 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to /mnt/data/GWAS/output/task2.2_stratification//1KG.chr11.bed +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr11.bim +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr11.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b3.45 64-bit (13 Jan 2017)      https://www.cog-genomics.org/plink2
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /mnt/data/GWAS/output/task2.2_stratification//1KG.chr12.log.
# Options in effect:
#   --make-bed
#   --out /mnt/data/GWAS/output/task2.2_stratification//1KG.chr12
#   --vcf /mnt/data/GWAS/output/task2.2_stratification//1KG.vcf.chr12.recode.vcf
#
# 32127 MB RAM detected; reserving 16063 MB for main workspace.
# --vcf: /mnt/data/GWAS/output/task2.2_stratification//1KG.chr12-temporary.bed +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr12-temporary.bim +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr12-temporary.fam written.
# 307031 variants loaded from .bim file.
# 2504 people (0 males, 0 females, 2504 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr12.nosex .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 2504 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.99985.
# 307031 variants and 2504 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to /mnt/data/GWAS/output/task2.2_stratification//1KG.chr12.bed +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr12.bim +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr12.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b3.45 64-bit (13 Jan 2017)      https://www.cog-genomics.org/plink2
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /mnt/data/GWAS/output/task2.2_stratification//1KG.chr13.log.
# Options in effect:
#   --make-bed
#   --out /mnt/data/GWAS/output/task2.2_stratification//1KG.chr13
#   --vcf /mnt/data/GWAS/output/task2.2_stratification//1KG.vcf.chr13.recode.vcf
#
# 32127 MB RAM detected; reserving 16063 MB for main workspace.
# --vcf: /mnt/data/GWAS/output/task2.2_stratification//1KG.chr13-temporary.bed +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr13-temporary.bim +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr13-temporary.fam written.
# 243551 variants loaded from .bim file.
# 2504 people (0 males, 0 females, 2504 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr13.nosex .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 2504 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.999859.
# 243551 variants and 2504 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to /mnt/data/GWAS/output/task2.2_stratification//1KG.chr13.bed +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr13.bim +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr13.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b3.45 64-bit (13 Jan 2017)      https://www.cog-genomics.org/plink2
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /mnt/data/GWAS/output/task2.2_stratification//1KG.chr14.log.
# Options in effect:
#   --make-bed
#   --out /mnt/data/GWAS/output/task2.2_stratification//1KG.chr14
#   --vcf /mnt/data/GWAS/output/task2.2_stratification//1KG.vcf.chr14.recode.vcf
#
# 32127 MB RAM detected; reserving 16063 MB for main workspace.
# --vcf: /mnt/data/GWAS/output/task2.2_stratification//1KG.chr14-temporary.bed +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr14-temporary.bim +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr14-temporary.fam written.
# 212995 variants loaded from .bim file.
# 2504 people (0 males, 0 females, 2504 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr14.nosex .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 2504 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.999849.
# 212995 variants and 2504 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to /mnt/data/GWAS/output/task2.2_stratification//1KG.chr14.bed +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr14.bim +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr14.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b3.45 64-bit (13 Jan 2017)      https://www.cog-genomics.org/plink2
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /mnt/data/GWAS/output/task2.2_stratification//1KG.chr15.log.
# Options in effect:
#   --make-bed
#   --out /mnt/data/GWAS/output/task2.2_stratification//1KG.chr15
#   --vcf /mnt/data/GWAS/output/task2.2_stratification//1KG.vcf.chr15.recode.vcf
#
# 32127 MB RAM detected; reserving 16063 MB for main workspace.
# --vcf: /mnt/data/GWAS/output/task2.2_stratification//1KG.chr15-temporary.bed +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr15-temporary.bim +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr15-temporary.fam written.
# 185833 variants loaded from .bim file.
# 2504 people (0 males, 0 females, 2504 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr15.nosex .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 2504 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.999847.
# 185833 variants and 2504 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to /mnt/data/GWAS/output/task2.2_stratification//1KG.chr15.bed +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr15.bim +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr15.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b3.45 64-bit (13 Jan 2017)      https://www.cog-genomics.org/plink2
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /mnt/data/GWAS/output/task2.2_stratification//1KG.chr16.log.
# Options in effect:
#   --make-bed
#   --out /mnt/data/GWAS/output/task2.2_stratification//1KG.chr16
#   --vcf /mnt/data/GWAS/output/task2.2_stratification//1KG.vcf.chr16.recode.vcf
#
# 32127 MB RAM detected; reserving 16063 MB for main workspace.
# --vcf: /mnt/data/GWAS/output/task2.2_stratification//1KG.chr16-temporary.bed +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr16-temporary.bim +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr16-temporary.fam written.
# 198791 variants loaded from .bim file.
# 2504 people (0 males, 0 females, 2504 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr16.nosex .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 2504 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.999813.
# 198791 variants and 2504 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to /mnt/data/GWAS/output/task2.2_stratification//1KG.chr16.bed +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr16.bim +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr16.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b3.45 64-bit (13 Jan 2017)      https://www.cog-genomics.org/plink2
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /mnt/data/GWAS/output/task2.2_stratification//1KG.chr17.log.
# Options in effect:
#   --make-bed
#   --out /mnt/data/GWAS/output/task2.2_stratification//1KG.chr17
#   --vcf /mnt/data/GWAS/output/task2.2_stratification//1KG.vcf.chr17.recode.vcf
#
# 32127 MB RAM detected; reserving 16063 MB for main workspace.
# --vcf: /mnt/data/GWAS/output/task2.2_stratification//1KG.chr17-temporary.bed +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr17-temporary.bim +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr17-temporary.fam written.
# 176044 variants loaded from .bim file.
# 2504 people (0 males, 0 females, 2504 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr17.nosex .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 2504 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.999858.
# 176044 variants and 2504 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to /mnt/data/GWAS/output/task2.2_stratification//1KG.chr17.bed +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr17.bim +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr17.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b3.45 64-bit (13 Jan 2017)      https://www.cog-genomics.org/plink2
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /mnt/data/GWAS/output/task2.2_stratification//1KG.chr18.log.
# Options in effect:
#   --make-bed
#   --out /mnt/data/GWAS/output/task2.2_stratification//1KG.chr18
#   --vcf /mnt/data/GWAS/output/task2.2_stratification//1KG.vcf.chr18.recode.vcf
#
# 32127 MB RAM detected; reserving 16063 MB for main workspace.
# --vcf: /mnt/data/GWAS/output/task2.2_stratification//1KG.chr18-temporary.bed +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr18-temporary.bim +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr18-temporary.fam written.
# 186082 variants loaded from .bim file.
# 2504 people (0 males, 0 females, 2504 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr18.nosex .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 2504 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.999853.
# 186082 variants and 2504 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to /mnt/data/GWAS/output/task2.2_stratification//1KG.chr18.bed +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr18.bim +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr18.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b3.45 64-bit (13 Jan 2017)      https://www.cog-genomics.org/plink2
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /mnt/data/GWAS/output/task2.2_stratification//1KG.chr19.log.
# Options in effect:
#   --make-bed
#   --out /mnt/data/GWAS/output/task2.2_stratification//1KG.chr19
#   --vcf /mnt/data/GWAS/output/task2.2_stratification//1KG.vcf.chr19.recode.vcf
#
# 32127 MB RAM detected; reserving 16063 MB for main workspace.
# --vcf: /mnt/data/GWAS/output/task2.2_stratification//1KG.chr19-temporary.bed +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr19-temporary.bim +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr19-temporary.fam written.
# 154398 variants loaded from .bim file.
# 2504 people (0 males, 0 females, 2504 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr19.nosex .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 2504 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.999834.
# 154398 variants and 2504 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to /mnt/data/GWAS/output/task2.2_stratification//1KG.chr19.bed +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr19.bim +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr19.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b3.45 64-bit (13 Jan 2017)      https://www.cog-genomics.org/plink2
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /mnt/data/GWAS/output/task2.2_stratification//1KG.chr20.log.
# Options in effect:
#   --make-bed
#   --out /mnt/data/GWAS/output/task2.2_stratification//1KG.chr20
#   --vcf /mnt/data/GWAS/output/task2.2_stratification//1KG.vcf.chr20.recode.vcf
#
# 32127 MB RAM detected; reserving 16063 MB for main workspace.
# --vcf: /mnt/data/GWAS/output/task2.2_stratification//1KG.chr20-temporary.bed +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr20-temporary.bim +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr20-temporary.fam written.
# 144774 variants loaded from .bim file.
# 2504 people (0 males, 0 females, 2504 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr20.nosex .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 2504 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.999857.
# 144774 variants and 2504 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to /mnt/data/GWAS/output/task2.2_stratification//1KG.chr20.bed +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr20.bim +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr20.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b3.45 64-bit (13 Jan 2017)      https://www.cog-genomics.org/plink2
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /mnt/data/GWAS/output/task2.2_stratification//1KG.chr21.log.
# Options in effect:
#   --make-bed
#   --out /mnt/data/GWAS/output/task2.2_stratification//1KG.chr21
#   --vcf /mnt/data/GWAS/output/task2.2_stratification//1KG.vcf.chr21.recode.vcf
#
# 32127 MB RAM detected; reserving 16063 MB for main workspace.
# --vcf: /mnt/data/GWAS/output/task2.2_stratification//1KG.chr21-temporary.bed +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr21-temporary.bim +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr21-temporary.fam written.
# 93739 variants loaded from .bim file.
# 2504 people (0 males, 0 females, 2504 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr21.nosex .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 2504 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.999823.
# 93739 variants and 2504 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to /mnt/data/GWAS/output/task2.2_stratification//1KG.chr21.bed +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr21.bim +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr21.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b3.45 64-bit (13 Jan 2017)      https://www.cog-genomics.org/plink2
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /mnt/data/GWAS/output/task2.2_stratification//1KG.chr22.log.
# Options in effect:
#   --make-bed
#   --out /mnt/data/GWAS/output/task2.2_stratification//1KG.chr22
#   --vcf /mnt/data/GWAS/output/task2.2_stratification//1KG.vcf.chr22.recode.vcf
#
# 32127 MB RAM detected; reserving 16063 MB for main workspace.
# --vcf: /mnt/data/GWAS/output/task2.2_stratification//1KG.chr22-temporary.bed +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr22-temporary.bim +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr22-temporary.fam written.
# 91208 variants loaded from .bim file.
# 2504 people (0 males, 0 females, 2504 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr22.nosex .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 2504 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.99982.
# 91208 variants and 2504 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to /mnt/data/GWAS/output/task2.2_stratification//1KG.chr22.bed +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr22.bim +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.chr22.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# VCFtools - UNKNOWN
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf /mnt/data/GWAS/input/Phase3_v5/ALL.chr1.phase3_shapeit2_mvncall_integrated_v5a.20130502.genotypes.clean.vcf.gz
# 	--out /mnt/data/GWAS/output/task2.2_stratification//1KG.vcf.chr1
# 	--recode
# 	--snps /mnt/data/GWAS/output/task2.2_stratification//mySNPlist.txt
#
# Using zlib version: 1.2.8
# Warning: Expected at least 2 parts in INFO entry: ID=PR,Number=0,Type=Flag,Description="Provisional reference allele, may not be based on real reference genome">
# After filtering, kept 2504 out of 2504 Individuals
# Outputting VCF file...
# After filtering, kept 497923 out of a possible 6467265 Sites
# Run Time = 610.00 seconds
#
# VCFtools - UNKNOWN
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf /mnt/data/GWAS/input/Phase3_v5/ALL.chr2.phase3_shapeit2_mvncall_integrated_v5a.20130502.genotypes.clean.vcf.gz
# 	--out /mnt/data/GWAS/output/task2.2_stratification//1KG.vcf.chr2
# 	--recode
# 	--snps /mnt/data/GWAS/output/task2.2_stratification//mySNPlist.txt
#
# Using zlib version: 1.2.8
# Warning: Expected at least 2 parts in INFO entry: ID=PR,Number=0,Type=Flag,Description="Provisional reference allele, may not be based on real reference genome">
# After filtering, kept 2504 out of 2504 Individuals
# Outputting VCF file...
# After filtering, kept 540431 out of a possible 7080712 Sites
# Run Time = 723.00 seconds
#
# VCFtools - UNKNOWN
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf /mnt/data/GWAS/input/Phase3_v5/ALL.chr3.phase3_shapeit2_mvncall_integrated_v5a.20130502.genotypes.clean.vcf.gz
# 	--out /mnt/data/GWAS/output/task2.2_stratification//1KG.vcf.chr3
# 	--recode
# 	--snps /mnt/data/GWAS/output/task2.2_stratification//mySNPlist.txt
#
# Using zlib version: 1.2.8
# Warning: Expected at least 2 parts in INFO entry: ID=PR,Number=0,Type=Flag,Description="Provisional reference allele, may not be based on real reference genome">
# After filtering, kept 2504 out of 2504 Individuals
# Outputting VCF file...
# After filtering, kept 462062 out of a possible 5831616 Sites
# Run Time = 538.00 seconds
#
# VCFtools - UNKNOWN
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf /mnt/data/GWAS/input/Phase3_v5/ALL.chr4.phase3_shapeit2_mvncall_integrated_v5a.20130502.genotypes.clean.vcf.gz
# 	--out /mnt/data/GWAS/output/task2.2_stratification//1KG.vcf.chr4
# 	--recode
# 	--snps /mnt/data/GWAS/output/task2.2_stratification//mySNPlist.txt
#
# Using zlib version: 1.2.8
# Warning: Expected at least 2 parts in INFO entry: ID=PR,Number=0,Type=Flag,Description="Provisional reference allele, may not be based on real reference genome">
# After filtering, kept 2504 out of 2504 Individuals
# Outputting VCF file...
# After filtering, kept 474260 out of a possible 5731977 Sites
# Run Time = 541.00 seconds
#
# VCFtools - UNKNOWN
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf /mnt/data/GWAS/input/Phase3_v5/ALL.chr5.phase3_shapeit2_mvncall_integrated_v5a.20130502.genotypes.clean.vcf.gz
# 	--out /mnt/data/GWAS/output/task2.2_stratification//1KG.vcf.chr5
# 	--recode
# 	--snps /mnt/data/GWAS/output/task2.2_stratification//mySNPlist.txt
#
# Using zlib version: 1.2.8
# Warning: Expected at least 2 parts in INFO entry: ID=PR,Number=0,Type=Flag,Description="Provisional reference allele, may not be based on real reference genome">
# After filtering, kept 2504 out of 2504 Individuals
# Outputting VCF file...
# After filtering, kept 410091 out of a possible 5265131 Sites
# Run Time = 481.00 seconds
#
# VCFtools - UNKNOWN
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf /mnt/data/GWAS/input/Phase3_v5/ALL.chr6.phase3_shapeit2_mvncall_integrated_v5a.20130502.genotypes.clean.vcf.gz
# 	--out /mnt/data/GWAS/output/task2.2_stratification//1KG.vcf.chr6
# 	--recode
# 	--snps /mnt/data/GWAS/output/task2.2_stratification//mySNPlist.txt
#
# Using zlib version: 1.2.8
# Warning: Expected at least 2 parts in INFO entry: ID=PR,Number=0,Type=Flag,Description="Provisional reference allele, may not be based on real reference genome">
# After filtering, kept 2504 out of 2504 Individuals
# Outputting VCF file...
# After filtering, kept 440932 out of a possible 5023483 Sites
# Run Time = 494.00 seconds
#
# VCFtools - UNKNOWN
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf /mnt/data/GWAS/input/Phase3_v5/ALL.chr7.phase3_shapeit2_mvncall_integrated_v5a.20130502.genotypes.clean.vcf.gz
# 	--out /mnt/data/GWAS/output/task2.2_stratification//1KG.vcf.chr7
# 	--recode
# 	--snps /mnt/data/GWAS/output/task2.2_stratification//mySNPlist.txt
#
# Using zlib version: 1.2.8
# Warning: Expected at least 2 parts in INFO entry: ID=PR,Number=0,Type=Flag,Description="Provisional reference allele, may not be based on real reference genome">
# After filtering, kept 2504 out of 2504 Individuals
# Outputting VCF file...
# After filtering, kept 384634 out of a possible 4716205 Sites
# Run Time = 474.00 seconds
#
# VCFtools - UNKNOWN
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf /mnt/data/GWAS/input/Phase3_v5/ALL.chr8.phase3_shapeit2_mvncall_integrated_v5a.20130502.genotypes.clean.vcf.gz
# 	--out /mnt/data/GWAS/output/task2.2_stratification//1KG.vcf.chr8
# 	--recode
# 	--snps /mnt/data/GWAS/output/task2.2_stratification//mySNPlist.txt
#
# Using zlib version: 1.2.8
# Warning: Expected at least 2 parts in INFO entry: ID=PR,Number=0,Type=Flag,Description="Provisional reference allele, may not be based on real reference genome">
# After filtering, kept 2504 out of 2504 Individuals
# Outputting VCF file...
# After filtering, kept 354504 out of a possible 4596555 Sites
# Run Time = 422.00 seconds
#
# VCFtools - UNKNOWN
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf /mnt/data/GWAS/input/Phase3_v5/ALL.chr9.phase3_shapeit2_mvncall_integrated_v5a.20130502.genotypes.clean.vcf.gz
# 	--out /mnt/data/GWAS/output/task2.2_stratification//1KG.vcf.chr9
# 	--recode
# 	--snps /mnt/data/GWAS/output/task2.2_stratification//mySNPlist.txt
#
# Using zlib version: 1.2.8
# Warning: Expected at least 2 parts in INFO entry: ID=PR,Number=0,Type=Flag,Description="Provisional reference allele, may not be based on real reference genome">
# After filtering, kept 2504 out of 2504 Individuals
# Outputting VCF file...
# After filtering, kept 281556 out of a possible 3560268 Sites
# Run Time = 337.00 seconds
#
# VCFtools - UNKNOWN
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf /mnt/data/GWAS/input/Phase3_v5/ALL.chr10.phase3_shapeit2_mvncall_integrated_v5a.20130502.genotypes.clean.vcf.gz
# 	--out /mnt/data/GWAS/output/task2.2_stratification//1KG.vcf.chr10
# 	--recode
# 	--snps /mnt/data/GWAS/output/task2.2_stratification//mySNPlist.txt
#
# Using zlib version: 1.2.8
# Warning: Expected at least 2 parts in INFO entry: ID=PR,Number=0,Type=Flag,Description="Provisional reference allele, may not be based on real reference genome">
# After filtering, kept 2504 out of 2504 Individuals
# Outputting VCF file...
# After filtering, kept 336853 out of a possible 3991662 Sites
# Run Time = 382.00 seconds
#
# VCFtools - UNKNOWN
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf /mnt/data/GWAS/input/Phase3_v5/ALL.chr11.phase3_shapeit2_mvncall_integrated_v5a.20130502.genotypes.clean.vcf.gz
# 	--out /mnt/data/GWAS/output/task2.2_stratification//1KG.vcf.chr11
# 	--recode
# 	--snps /mnt/data/GWAS/output/task2.2_stratification//mySNPlist.txt
#
# Using zlib version: 1.2.8
# Warning: Expected at least 2 parts in INFO entry: ID=PR,Number=0,Type=Flag,Description="Provisional reference allele, may not be based on real reference genome">
# After filtering, kept 2504 out of 2504 Individuals
# Outputting VCF file...
# After filtering, kept 328068 out of a possible 4045150 Sites
# Run Time = 383.00 seconds
#
# VCFtools - UNKNOWN
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf /mnt/data/GWAS/input/Phase3_v5/ALL.chr12.phase3_shapeit2_mvncall_integrated_v5a.20130502.genotypes.clean.vcf.gz
# 	--out /mnt/data/GWAS/output/task2.2_stratification//1KG.vcf.chr12
# 	--recode
# 	--snps /mnt/data/GWAS/output/task2.2_stratification//mySNPlist.txt
#
# Using zlib version: 1.2.8
# Warning: Expected at least 2 parts in INFO entry: ID=PR,Number=0,Type=Flag,Description="Provisional reference allele, may not be based on real reference genome">
# After filtering, kept 2504 out of 2504 Individuals
# Outputting VCF file...
# After filtering, kept 307031 out of a possible 3867557 Sites
# Run Time = 359.00 seconds
#
# VCFtools - UNKNOWN
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf /mnt/data/GWAS/input/Phase3_v5/ALL.chr13.phase3_shapeit2_mvncall_integrated_v5a.20130502.genotypes.clean.vcf.gz
# 	--out /mnt/data/GWAS/output/task2.2_stratification//1KG.vcf.chr13
# 	--recode
# 	--snps /mnt/data/GWAS/output/task2.2_stratification//mySNPlist.txt
#
# Using zlib version: 1.2.8
# Warning: Expected at least 2 parts in INFO entry: ID=PR,Number=0,Type=Flag,Description="Provisional reference allele, may not be based on real reference genome">
# After filtering, kept 2504 out of 2504 Individuals
# Outputting VCF file...
# After filtering, kept 243551 out of a possible 2857612 Sites
# Run Time = 279.00 seconds
#
# VCFtools - UNKNOWN
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf /mnt/data/GWAS/input/Phase3_v5/ALL.chr14.phase3_shapeit2_mvncall_integrated_v5a.20130502.genotypes.clean.vcf.gz
# 	--out /mnt/data/GWAS/output/task2.2_stratification//1KG.vcf.chr14
# 	--recode
# 	--snps /mnt/data/GWAS/output/task2.2_stratification//mySNPlist.txt
#
# Using zlib version: 1.2.8
# Warning: Expected at least 2 parts in INFO entry: ID=PR,Number=0,Type=Flag,Description="Provisional reference allele, may not be based on real reference genome">
# After filtering, kept 2504 out of 2504 Individuals
# Outputting VCF file...
# After filtering, kept 212995 out of a possible 2654741 Sites
# Run Time = 253.00 seconds
#
# VCFtools - UNKNOWN
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf /mnt/data/GWAS/input/Phase3_v5/ALL.chr15.phase3_shapeit2_mvncall_integrated_v5a.20130502.genotypes.clean.vcf.gz
# 	--out /mnt/data/GWAS/output/task2.2_stratification//1KG.vcf.chr15
# 	--recode
# 	--snps /mnt/data/GWAS/output/task2.2_stratification//mySNPlist.txt
#
# Using zlib version: 1.2.8
# Warning: Expected at least 2 parts in INFO entry: ID=PR,Number=0,Type=Flag,Description="Provisional reference allele, may not be based on real reference genome">
# After filtering, kept 2504 out of 2504 Individuals
# Outputting VCF file...
# After filtering, kept 185833 out of a possible 2424342 Sites
# Run Time = 224.00 seconds
#
# VCFtools - UNKNOWN
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf /mnt/data/GWAS/input/Phase3_v5/ALL.chr16.phase3_shapeit2_mvncall_integrated_v5a.20130502.genotypes.clean.vcf.gz
# 	--out /mnt/data/GWAS/output/task2.2_stratification//1KG.vcf.chr16
# 	--recode
# 	--snps /mnt/data/GWAS/output/task2.2_stratification//mySNPlist.txt
#
# Using zlib version: 1.2.8
# Warning: Expected at least 2 parts in INFO entry: ID=PR,Number=0,Type=Flag,Description="Provisional reference allele, may not be based on real reference genome">
# After filtering, kept 2504 out of 2504 Individuals
# Outputting VCF file...
# After filtering, kept 198791 out of a possible 2697571 Sites
# Run Time = 246.00 seconds
#
# VCFtools - UNKNOWN
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf /mnt/data/GWAS/input/Phase3_v5/ALL.chr17.phase3_shapeit2_mvncall_integrated_v5a.20130502.genotypes.clean.vcf.gz
# 	--out /mnt/data/GWAS/output/task2.2_stratification//1KG.vcf.chr17
# 	--recode
# 	--snps /mnt/data/GWAS/output/task2.2_stratification//mySNPlist.txt
#
# Using zlib version: 1.2.8
# Warning: Expected at least 2 parts in INFO entry: ID=PR,Number=0,Type=Flag,Description="Provisional reference allele, may not be based on real reference genome">
# After filtering, kept 2504 out of 2504 Individuals
# Outputting VCF file...
# After filtering, kept 176044 out of a possible 2328930 Sites
# Run Time = 214.00 seconds
#
# VCFtools - UNKNOWN
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf /mnt/data/GWAS/input/Phase3_v5/ALL.chr18.phase3_shapeit2_mvncall_integrated_v5a.20130502.genotypes.clean.vcf.gz
# 	--out /mnt/data/GWAS/output/task2.2_stratification//1KG.vcf.chr18
# 	--recode
# 	--snps /mnt/data/GWAS/output/task2.2_stratification//mySNPlist.txt
#
# Using zlib version: 1.2.8
# Warning: Expected at least 2 parts in INFO entry: ID=PR,Number=0,Type=Flag,Description="Provisional reference allele, may not be based on real reference genome">
# After filtering, kept 2504 out of 2504 Individuals
# Outputting VCF file...
# After filtering, kept 186082 out of a possible 2266920 Sites
# Run Time = 219.00 seconds
#
# VCFtools - UNKNOWN
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf /mnt/data/GWAS/input/Phase3_v5/ALL.chr19.phase3_shapeit2_mvncall_integrated_v5a.20130502.genotypes.clean.vcf.gz
# 	--out /mnt/data/GWAS/output/task2.2_stratification//1KG.vcf.chr19
# 	--recode
# 	--snps /mnt/data/GWAS/output/task2.2_stratification//mySNPlist.txt
#
# Using zlib version: 1.2.8
# Warning: Expected at least 2 parts in INFO entry: ID=PR,Number=0,Type=Flag,Description="Provisional reference allele, may not be based on real reference genome">
# After filtering, kept 2504 out of 2504 Individuals
# Outputting VCF file...
# After filtering, kept 154398 out of a possible 1832210 Sites
# Run Time = 181.00 seconds
#
# VCFtools - UNKNOWN
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf /mnt/data/GWAS/input/Phase3_v5/ALL.chr20.phase3_shapeit2_mvncall_integrated_v5a.20130502.genotypes.clean.vcf.gz
# 	--out /mnt/data/GWAS/output/task2.2_stratification//1KG.vcf.chr20
# 	--recode
# 	--snps /mnt/data/GWAS/output/task2.2_stratification//mySNPlist.txt
#
# Using zlib version: 1.2.8
# Warning: Expected at least 2 parts in INFO entry: ID=PR,Number=0,Type=Flag,Description="Provisional reference allele, may not be based on real reference genome">
# After filtering, kept 2504 out of 2504 Individuals
# Outputting VCF file...
# After filtering, kept 144774 out of a possible 1812578 Sites
# Run Time = 172.00 seconds
#
# VCFtools - UNKNOWN
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf /mnt/data/GWAS/input/Phase3_v5/ALL.chr21.phase3_shapeit2_mvncall_integrated_v5a.20130502.genotypes.clean.vcf.gz
# 	--out /mnt/data/GWAS/output/task2.2_stratification//1KG.vcf.chr21
# 	--recode
# 	--snps /mnt/data/GWAS/output/task2.2_stratification//mySNPlist.txt
#
# Using zlib version: 1.2.8
# Warning: Expected at least 2 parts in INFO entry: ID=PR,Number=0,Type=Flag,Description="Provisional reference allele, may not be based on real reference genome">
# After filtering, kept 2504 out of 2504 Individuals
# Outputting VCF file...
# After filtering, kept 93739 out of a possible 1105434 Sites
# Run Time = 112.00 seconds
#
# VCFtools - UNKNOWN
# (C) Adam Auton and Anthony Marcketta 2009
#
# Parameters as interpreted:
# 	--gzvcf /mnt/data/GWAS/input/Phase3_v5/ALL.chr22.phase3_shapeit2_mvncall_integrated_v5a.20130502.genotypes.clean.vcf.gz
# 	--out /mnt/data/GWAS/output/task2.2_stratification//1KG.vcf.chr22
# 	--recode
# 	--snps /mnt/data/GWAS/output/task2.2_stratification//mySNPlist.txt
#
# Using zlib version: 1.2.8
# Warning: Expected at least 2 parts in INFO entry: ID=PR,Number=0,Type=Flag,Description="Provisional reference allele, may not be based on real reference genome">
# After filtering, kept 2504 out of 2504 Individuals
# Outputting VCF file...
# After filtering, kept 91208 out of a possible 1103411 Sites
# Run Time = 107.00 seconds

# %%
# %%bash
# # Creates a file with the list of bfiles (.bim, .bed, .fam) outputed in the previous step
# # 1st-3rd parameter: path to previous plink files
# # 4th parameter: output file
# for i in {2..22}
# do
# echo $path/1KG.chr$i.bed $path/1KG.chr$i.bim $path/1KG.chr$i.fam >> $path/1KG.outlist.txt
# done

# %%
# %%bash
# # Merge all bfiles into a single one
# plink --bfile $path/1KG.chr1 --make-bed --merge-list $path/1KG.outlist.txt --out $path/1KG.all
# Out:
# PLINK v1.90b3.45 64-bit (13 Jan 2017)      https://www.cog-genomics.org/plink2
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /mnt/data/GWAS/output/task2.2_stratification//1KG.all.log.
# Options in effect:
#   --bfile /mnt/data/GWAS/output/task2.2_stratification//1KG.chr1
#   --make-bed
#   --merge-list /mnt/data/GWAS/output/task2.2_stratification//1KG.outlist.txt
#   --out /mnt/data/GWAS/output/task2.2_stratification//1KG.all
#
# 32127 MB RAM detected; reserving 16063 MB for main workspace.
# Performing single-pass merge (2504 people, 6505760 variants).
# Merged fileset written to
# /mnt/data/GWAS/output/task2.2_stratification//1KG.all-merge.bed +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.all-merge.bim +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.all-merge.fam .
# 6505760 variants loaded from .bim file.
# 2504 people (0 males, 0 females, 2504 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# /mnt/data/GWAS/output/task2.2_stratification//1KG.all.nosex .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 2504 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.999848.
# 6505760 variants and 2504 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to /mnt/data/GWAS/output/task2.2_stratification//1KG.all.bed +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.all.bim +
# /mnt/data/GWAS/output/task2.2_stratification//1KG.all.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.

# %%
# %%bash
# # remove individual chr plink files
# for i in {2..22}
# do
# rm $path/1KG.chr$i.*
# done

# %% [markdown]
# ## QC
#
# 1000 Genomes Dataset after this QC is provided (1kG.QCed.forMDS). There is no need to run these steps.

# %%
# %%bash
# # Remove variants based on missing genotype data.
# plink --bfile $path/1KG.all --geno 0.05 --allow-no-sex --make-bed --out $intpath/1kG_MDS
# Out:
# PLINK v1.90b3.45 64-bit (13 Jan 2017)      https://www.cog-genomics.org/plink2
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /mnt/data/GWAS/output/task2.2_stratification/intermediate_datasets/1kG_MDS.log.
# Options in effect:
#   --allow-no-sex
#   --bfile /mnt/data/GWAS/output/task2.2_stratification/1KG.all
#   --geno 0.05
#   --make-bed
#   --out /mnt/data/GWAS/output/task2.2_stratification/intermediate_datasets/1kG_MDS
#
# 32127 MB RAM detected; reserving 16063 MB for main workspace.
# 6505760 variants loaded from .bim file.
# 2504 people (0 males, 0 females, 2504 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# /mnt/data/GWAS/output/task2.2_stratification/intermediate_datasets/1kG_MDS.nosex
# .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 2504 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.999848.
# 5572 variants removed due to missing genotype data (--geno).
# 6500188 variants and 2504 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to
# /mnt/data/GWAS/output/task2.2_stratification/intermediate_datasets/1kG_MDS.bed
# +
# /mnt/data/GWAS/output/task2.2_stratification/intermediate_datasets/1kG_MDS.bim
# +
# /mnt/data/GWAS/output/task2.2_stratification/intermediate_datasets/1kG_MDS.fam
# ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.

# %%
# %%bash
# # Remove individuals based on missing genotype data.
# plink --bfile $intpath/1kG_MDS --mind 0.03 --allow-no-sex --make-bed --out $intpath/1kG_MDS2
# Out:
# PLINK v1.90b3.45 64-bit (13 Jan 2017)      https://www.cog-genomics.org/plink2
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /mnt/data/GWAS/output/task2.2_stratification/intermediate_datasets/1kG_MDS2.log.
# Options in effect:
#   --allow-no-sex
#   --bfile /mnt/data/GWAS/output/task2.2_stratification/intermediate_datasets/1kG_MDS
#   --make-bed
#   --mind 0.03
#   --out /mnt/data/GWAS/output/task2.2_stratification/intermediate_datasets/1kG_MDS2
#
# 32127 MB RAM detected; reserving 16063 MB for main workspace.
# 6500188 variants loaded from .bim file.
# 2504 people (0 males, 0 females, 2504 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# /mnt/data/GWAS/output/task2.2_stratification/intermediate_datasets/1kG_MDS2.nosex
# .
# 0 people removed due to missing genotype data (--mind).
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 2504 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.999931.
# 6500188 variants and 2504 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to
# /mnt/data/GWAS/output/task2.2_stratification/intermediate_datasets/1kG_MDS2.bed
# +
# /mnt/data/GWAS/output/task2.2_stratification/intermediate_datasets/1kG_MDS2.bim
# +
# /mnt/data/GWAS/output/task2.2_stratification/intermediate_datasets/1kG_MDS2.fam
# ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.

# %%
# %%bash
# # Remove variants based on MAF.
# plink --bfile $intpath/1kG_MDS2 --maf 0.05 --allow-no-sex --make-bed --out $intpath/1kG_MDS3
# Out:
# PLINK v1.90b3.45 64-bit (13 Jan 2017)      https://www.cog-genomics.org/plink2
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to /mnt/data/GWAS/output/task2.2_stratification/intermediate_datasets/1kG_MDS3.log.
# Options in effect:
#   --allow-no-sex
#   --bfile /mnt/data/GWAS/output/task2.2_stratification/intermediate_datasets/1kG_MDS2
#   --maf 0.05
#   --make-bed
#   --out /mnt/data/GWAS/output/task2.2_stratification/intermediate_datasets/1kG_MDS3
#
# 32127 MB RAM detected; reserving 16063 MB for main workspace.
# 6500188 variants loaded from .bim file.
# 2504 people (0 males, 0 females, 2504 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# /mnt/data/GWAS/output/task2.2_stratification/intermediate_datasets/1kG_MDS3.nosex
# .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 2504 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.999931.
# 452774 variants removed due to minor allele threshold(s)
# (--maf/--max-maf/--mac/--max-mac).
# 6047414 variants and 2504 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to
# /mnt/data/GWAS/output/task2.2_stratification/intermediate_datasets/1kG_MDS3.bed
# +
# /mnt/data/GWAS/output/task2.2_stratification/intermediate_datasets/1kG_MDS3.bim
# +
# /mnt/data/GWAS/output/task2.2_stratification/intermediate_datasets/1kG_MDS3.fam
# ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.

# %% [markdown]
# **For the next step you need the following files:**
# - 1kG_MDS3 (the bfile, i.e., 1kG_MDS3.bed, 1kG_MDS3.bim, and 1kG_MDS3.fam
